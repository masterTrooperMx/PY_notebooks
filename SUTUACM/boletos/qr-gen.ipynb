# %%
# instalar biblioteca
# !pip install qrcode[pil]
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# import modules
import qrcode
from PIL import Image
from qrcode.image.styledpil import StyledPilImage
from qrcode.image.styles.colormasks import ImageColorMask

# taking image which user wants
# in the QR code center
#Logo_link = './sutuacm_redondo__400x400.jpg'
Logo_link = './logo_jesus_cruz_2.png'

logo = Image.open(Logo_link)

# taking base width
basewidth = 100

# adjust image size
wpercent = (basewidth/float(logo.size[0]))
hsize = int((float(logo.size[1])*float(wpercent)))
logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)
QRcode = qrcode.QRCode(
	error_correction=qrcode.constants.ERROR_CORRECT_H,
    version = 2,
    box_size = 12,
)

# taking url or text
url = 'https://www.linkedin.com/in/jesuscruzmartinez/'

# adding URL or text to QRcode
QRcode.add_data(url)

# generating QR code
QRcode.make()

# taking color name from user
QRcolor = 'Red'

# adding color to QR code
QRimg = QRcode.make_image(
    image_factory=StyledPilImage,
    #color_mask=ImageColorMask(VerticalGradiantColorMask()),
	fill_color=QRcolor, back_color="white").convert('RGB'),

# set size of QR code
pos = ((QRimg.size[0] - logo.size[0]) // 2,
	(QRimg.size[1] - logo.size[1]) // 2)
QRimg.paste(logo, pos)

# save the QR code generated
#QRimg.save('gfg_QR.png')
QRimg.save('qr_jesus.png')

print('QR code generated!')
# Out:
# QR code generated!

# %%
# ponle info y los atributos como esperamos
# import modules
import qrcode
from PIL import Image

data = ['ALEJANDRA', 'ESTRADA', 'HERNADEZ', '2005110245', '639']

def generaTicket(lista):
    # taking image which user wants
    # in the QR code center
    Logo_link = './sutuacm_redondo__400x400.jpg'

    logo = Image.open(Logo_link)

    # taking base width
    basewidth = 100

    # adjust image size
    wpercent = (basewidth/float(logo.size[0]))
    hsize = int((float(logo.size[1])*float(wpercent)))
    logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)
    QRcode = qrcode.QRCode(
        error_correction=qrcode.constants.ERROR_CORRECT_H
    )

    # taking data and put it right
    data = f"Nombre:{lista[0]} {lista[1]} {lista[2]}, Empleado: {lista[3]}, Boleto: {lista[4]}"

    # adding URL or text to QRcode
    QRcode.add_data(data)

    # generating QR code
    QRcode.make()

    # taking color name from user
    QRcolor = 'orangered'

    # adding color to QR code
    QRimg = QRcode.make_image(
        fill_color=QRcolor, back_color="white").convert('RGB')

    # set size of QR code
    pos = ((QRimg.size[0] - logo.size[0]) // 2,
        (QRimg.size[1] - logo.size[1]) // 2)
    QRimg.paste(logo, pos)

    # save the QR code generated
    QRimg.save(f"./boletos/boleto_{lista[3]}_{lista[4]}.png")

    print('boleto', lista[4])

generaTicket(data)
# Out:
# boleto 639

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 8.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
# leer la lista de boletos de un csv
# luego imprimir los que tengan el campo Procede <> de NO
import pandas as pd

df = pd.read_csv('lista_boletos.csv', index_col='marca_temporal', na_filter= False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 19/11/2022 2:07:27 to AL ULTIMO
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nombre(s)           59 non-null     object
#  1   apellido_paterno    59 non-null     object
#  2   apellido_materno    59 non-null     object
#  3   número_de_empleado  59 non-null     object
#  4   email               59 non-null     object
#  5   boleto              59 non-null     int64
#  6   procede             59 non-null     object
#  7   razón               59 non-null     object
#  8   Unnamed: 9          59 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 4.6+ KB

# %%
df[['nombre(s)', 'apellido_paterno', 'apellido_materno', 'número_de_empleado','boleto']]
# Out:
#                             nombre(s) apellido_paterno apellido_materno  \
# marca_temporal
# 19/11/2022 2:07:27           INVITADO               DE            HONOR
# 20/11/2022 2:07:27           INVITADO               DE            HONOR
# 21/11/2022 2:07:27           INVITADO               DE            HONOR
# 22/11/2022 2:07:27           INVITADO               DE            HONOR
# 23/11/2022 2:07:27           INVITADO               DE            HONOR
# 24/11/2022 2:07:27           INVITADO               DE            HONOR
# 25/11/2022 2:07:27           INVITADO               DE            HONOR
# 26/11/2022 2:07:27           INVITADO               DE            HONOR
# 27/11/2022 2:07:27           INVITADO               DE            HONOR
# 28/11/2022 2:07:27           INVITADO               DE            HONOR
# 29/11/2022 2:07:27           INVITADO               DE            HONOR
# 30/11/2022 2:07:27           INVITADO               DE            HONOR
# ...

# %%
# despliega solo los que no deicen NO
df_boletos = df[df['procede'] != 'NO'][['nombre(s)', 'apellido_paterno', 'apellido_materno', 'número_de_empleado','boleto']]
df_boletos
# Out:
#                             nombre(s) apellido_paterno apellido_materno  \
# marca_temporal
# 19/11/2022 2:07:27           INVITADO               DE            HONOR
# 20/11/2022 2:07:27           INVITADO               DE            HONOR
# 21/11/2022 2:07:27           INVITADO               DE            HONOR
# 22/11/2022 2:07:27           INVITADO               DE            HONOR
# 23/11/2022 2:07:27           INVITADO               DE            HONOR
# 24/11/2022 2:07:27           INVITADO               DE            HONOR
# 25/11/2022 2:07:27           INVITADO               DE            HONOR
# 26/11/2022 2:07:27           INVITADO               DE            HONOR
# 27/11/2022 2:07:27           INVITADO               DE            HONOR
# 28/11/2022 2:07:27           INVITADO               DE            HONOR
# 29/11/2022 2:07:27           INVITADO               DE            HONOR
# 30/11/2022 2:07:27           INVITADO               DE            HONOR
# ...

# %%
# ahora hay que generar los QRs
ls_boletos = df_boletos.values.tolist()
for registro in ls_boletos:
    nombre = f"{registro[0]} {registro[1]} {registro[2]}"
    no_empleado = registro[3]
    boleto = registro[4]
    generaTicket(registro)
    print(nombre, no_empleado, boleto)
print(len(ls_boletos))
# Out:
# boleto 251
# INVITADO DE HONOR XXXXXXX 251
# boleto 252
# INVITADO DE HONOR XXXXXXX 252
# boleto 253
# INVITADO DE HONOR XXXXXXX 253
# boleto 254
# INVITADO DE HONOR XXXXXXX 254
# boleto 255
# INVITADO DE HONOR XXXXXXX 255
# boleto 256
# INVITADO DE HONOR XXXXXXX 256
# boleto 258
# INVITADO DE HONOR XXXXXXX 258
# boleto 259
# INVITADO DE HONOR XXXXXXX 259
# boleto 260
# INVITADO DE HONOR XXXXXXX 260
# boleto 261
# INVITADO DE HONOR XXXXXXX 261
# boleto 262
# INVITADO DE HONOR XXXXXXX 262
# boleto 263
# INVITADO DE HONOR XXXXXXX 263
# boleto 264
# INVITADO DE HONOR XXXXXXX 264
# boleto 265
# INVITADO DE HONOR XXXXXXX 265
# boleto 266
# INVITADO DE HONOR XXXXXXX 266
# boleto 267
# INVITADO DE HONOR XXXXXXX 267
# boleto 268
# INVITADO DE HONOR XXXXXXX 268
# boleto 269
# INVITADO DE HONOR XXXXXXX 269
# boleto 270
# INVITADO DE HONOR XXXXXXX 270
# boleto 271
# INVITADO DE HONOR XXXXXXX 271
# boleto 272
# INVITADO DE HONOR XXXXXXX 272
# boleto 273
# INVITADO DE HONOR XXXXXXX 273
# ...

# %%
# vamos a pegar las imagenes utilizando la biblioteca ImageMagick
# en un ciclo vamos a reducir todos los QRs
import os
dir = "./boletos"
for qr in os.listdir(dir):
    # vamos a reducir todos los qrs
    resize_qr = f"convert {dir}/{qr} -resize 478x478 {dir}/{qr}"
    res = os.system(resize_qr)
    print(res)
    # vamos a crear el fondo de los boletos
    create_bkgrd = f"convert -size 1736x478 xc:white {dir}/dic_{qr}"
    res = os.system(create_bkgrd)
    print(res)
    # pegamos la primera parte al boleto
    glue_first = f"composite -geometry  +0+0 ./b_der.png {dir}/dic_{qr} {dir}/dic_{qr}"
    res = os.system(glue_first)
    print(res)
    # pegamos la segunda parte
    glue_second = f"composite -geometry  +868+0 ./b_izq.png {dir}/dic_{qr} {dir}/dic_{qr}"
    res = os.system(glue_second)
    print(res)
    # pegamos el qr
    glue_third = f"composite -geometry  +1086+0 {dir}/{qr} {dir}/dic_{qr} {dir}/dic_{qr}"
    res = os.system(glue_third)
    print(res)
    print(qr)
# Out:
# convert convert: No decode delegate for this image format (/tmp/gmTPaKU6).
# convert convert: No encode delegate for this image format (XC) [No existe el archivo o el directorio].
# composite composite: Unable to open file (./boletos/dic_boletos1-tar.gz) [No existe el archivo o el directorio].
# composite composite: Unable to open file (./boletos/dic_boletos1-tar.gz) [No existe el archivo o el directorio].
# 256
# 256
# 256
# 256
# composite composite: No decode delegate for this image format (/tmp/gmF3cUhm).
# convert convert: No decode delegate for this image format (./boletos/boletos2-.tar.xz).
# convert convert: No encode delegate for this image format (XZ) [No existe el archivo o el directorio].
# composite composite: Unable to open file (./boletos/dic_boletos2-.tar.xz) [No existe el archivo o el directorio].
# composite composite: Unable to open file (./boletos/dic_boletos2-.tar.xz) [No existe el archivo o el directorio].
# ...
