# %%
# instala mido
#pip install mido
# Out:
#   File "/var/folders/s8/2lk1tq9d6_31q71bjqgm6kk40000gn/T/ipykernel_33938/3954521327.py", line 2
#     pip install mido
#         ^
# SyntaxError: invalid syntax

# %%
# Manipulación de datos
import pandas as pd
import numpy as np

# %%
import mido
# todos los tracks del archivo
mid = mido.MidiFile('./Yesterday(StringsOnly).mid', clip=True)
mid.tracks
# Out:
# [MidiTrack([
#    MetaMessage('track_name', name='Yesterday', time=0),
#    MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#    MetaMessage('key_signature', key='F', time=0),
#    MetaMessage('set_tempo', tempo=631577, time=0),
#    Message('program_change', channel=2, program=40, time=0),
#    Message('control_change', channel=2, control=11, value=100, time=0),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('control_change', channel=2, control=101, value=0, time=0),
#    Message('control_change', channel=2, control=100, value=0, time=0),
#    Message('control_change', channel=2, control=6, value=6, time=0),
#    Message('program_change', channel=3, program=40, time=0),
#    Message('control_change', channel=3, control=11, value=100, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('control_change', channel=3, control=101, value=0, time=0),
#    Message('control_change', channel=3, control=100, value=0, time=0),
#    Message('control_change', channel=3, control=6, value=6, time=0),
#    Message('program_change', channel=4, program=41, time=0),
#    Message('control_change', channel=4, control=11, value=100, time=0),
#    Message('note_on', channel=4, note=60, velocity=56, time=0),
#    Message('control_change', channel=4, control=101, value=0, time=0),
#    Message('control_change', channel=4, control=100, value=0, time=0),
#    Message('control_change', channel=4, control=6, value=6, time=0),
#    Message('program_change', channel=5, program=42, time=0),
#    Message('note_on', channel=5, note=53, velocity=56, time=0),
#    Message('control_change', channel=5, control=101, value=0, time=0),
#    Message('control_change', channel=5, control=100, value=0, time=0),
#    Message('control_change', channel=5, control=6, value=6, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=1920),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=60, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=53, velocity=0, time=0),
#    Message('note_on', channel=5, note=52, velocity=56, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=52, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=1440),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=58, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=58, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=240),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=40, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=40, velocity=0, time=0),
#    Message('note_on', channel=5, note=38, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=38, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=58, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=58, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=1200),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=480),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=480),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=480),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=240),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=960),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=36, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=36, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=1920),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=480),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=480),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=480),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=240),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=960),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=36, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=77, velocity=80, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=36, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=77, velocity=0, time=480),
#    Message('note_on', channel=2, note=72, velocity=80, time=0),
#    Message('note_off', channel=2, note=72, velocity=0, time=480),
#    Message('note_on', channel=2, note=70, velocity=80, time=0),
#    Message('note_off', channel=2, note=70, velocity=0, time=480),
#    Message('note_on', channel=2, note=69, velocity=80, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=480),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=60, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=53, velocity=56, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=1920),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=60, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=53, velocity=0, time=0),
#    Message('note_on', channel=5, note=52, velocity=56, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=52, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=1440),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=58, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=58, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=240),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=40, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=40, velocity=0, time=0),
#    Message('note_on', channel=5, note=38, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=38, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=58, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=58, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=1200),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=480),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=480),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=720),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=36, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=60, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=56, time=0),
#    Message('note_off', channel=5, note=36, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=80, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=480),
#    Message('note_on', channel=5, note=48, velocity=80, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=420),
#    Message('note_on', channel=5, note=50, velocity=80, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=60),
#    Message('note_on', channel=5, note=51, velocity=80, time=0),
#    Message('control_change', channel=5, control=1, value=13, time=24),
#    Message('control_change', channel=5, control=1, value=11, time=48),
#    Message('control_change', channel=5, control=1, value=5, time=48),
#    Message('control_change', channel=5, control=1, value=10, time=48),
#    Message('control_change', channel=5, control=1, value=2, time=48),
#    Message('control_change', channel=5, control=1, value=4, time=48),
#    Message('control_change', channel=5, control=1, value=16, time=48),
#    Message('control_change', channel=5, control=1, value=14, time=48),
#    Message('control_change', channel=5, control=1, value=7, time=48),
#    Message('control_change', channel=5, control=1, value=11, time=48),
#    Message('control_change', channel=5, control=1, value=0, time=19),
#    Message('note_off', channel=5, note=51, velocity=0, time=5),
#    Message('note_on', channel=5, note=48, velocity=80, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=240),
#    Message('note_on', channel=5, note=46, velocity=80, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=62, velocity=56, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=56, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=62, velocity=0, time=960),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=61, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=61, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=480),
#    Message('note_on', channel=2, note=69, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('note_off', channel=2, note=69, velocity=0, time=480),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=67, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=56, time=0),
#    Message('note_off', channel=2, note=67, velocity=0, time=720),
#    Message('note_on', channel=2, note=65, velocity=56, time=0),
#    Message('note_off', channel=3, note=64, velocity=0, time=0),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=64, velocity=56, time=0),
#    Message('note_off', channel=3, note=62, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=56, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=36, velocity=56, time=0),
#    Message('note_off', channel=2, note=64, velocity=0, time=960),
#    Message('note_on', channel=2, note=77, velocity=56, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('note_off', channel=5, note=36, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('note_off', channel=2, note=77, velocity=0, time=1920),
#    Message('control_change', channel=2, control=11, value=0, time=0),
#    Message('note_on', channel=2, note=93, velocity=56, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=69, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=60, velocity=56, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=53, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=1, time=48),
#    Message('control_change', channel=2, control=11, value=2, time=96),
#    Message('control_change', channel=2, control=11, value=3, time=96),
#    Message('control_change', channel=2, control=11, value=4, time=96),
#    Message('control_change', channel=2, control=11, value=5, time=96),
#    Message('control_change', channel=2, control=11, value=6, time=96),
#    Message('control_change', channel=2, control=11, value=7, time=96),
#    Message('control_change', channel=2, control=11, value=8, time=96),
#    Message('control_change', channel=2, control=11, value=9, time=96),
#    Message('control_change', channel=2, control=11, value=10, time=96),
#    Message('control_change', channel=2, control=11, value=11, time=96),
#    Message('control_change', channel=2, control=11, value=12, time=96),
#    Message('control_change', channel=2, control=11, value=13, time=96),
#    Message('control_change', channel=2, control=11, value=14, time=96),
#    Message('control_change', channel=2, control=11, value=15, time=96),
#    Message('control_change', channel=2, control=11, value=16, time=96),
#    Message('control_change', channel=2, control=11, value=17, time=96),
#    Message('control_change', channel=2, control=11, value=18, time=96),
#    Message('control_change', channel=2, control=11, value=19, time=96),
#    Message('control_change', channel=2, control=11, value=20, time=96),
#    Message('note_off', channel=3, note=69, velocity=0, time=48),
#    Message('note_on', channel=3, note=67, velocity=56, time=0),
#    Message('note_off', channel=4, note=60, velocity=0, time=0),
#    Message('note_on', channel=4, note=59, velocity=56, time=0),
#    Message('note_off', channel=5, note=53, velocity=0, time=0),
#    Message('note_on', channel=5, note=52, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=21, time=48),
#    Message('control_change', channel=2, control=11, value=22, time=96),
#    Message('control_change', channel=2, control=11, value=23, time=96),
#    Message('control_change', channel=2, control=11, value=24, time=96),
#    Message('control_change', channel=2, control=11, value=25, time=96),
#    Message('control_change', channel=2, control=11, value=26, time=96),
#    Message('control_change', channel=2, control=11, value=27, time=144),
#    Message('control_change', channel=2, control=11, value=28, time=48),
#    Message('control_change', channel=2, control=11, value=29, time=96),
#    Message('control_change', channel=2, control=11, value=30, time=144),
#    Message('note_off', channel=3, note=67, velocity=0, time=0),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=59, velocity=0, time=0),
#    Message('note_on', channel=4, note=61, velocity=56, time=0),
#    Message('note_off', channel=5, note=52, velocity=0, time=0),
#    Message('note_on', channel=5, note=45, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=31, time=48),
#    Message('control_change', channel=2, control=11, value=32, time=96),
#    Message('control_change', channel=2, control=11, value=33, time=96),
#    Message('control_change', channel=2, control=11, value=34, time=96),
#    Message('control_change', channel=2, control=11, value=35, time=96),
#    Message('control_change', channel=2, control=11, value=36, time=96),
#    Message('control_change', channel=2, control=11, value=37, time=96),
#    Message('control_change', channel=2, control=11, value=38, time=96),
#    Message('control_change', channel=2, control=11, value=39, time=96),
#    Message('control_change', channel=2, control=11, value=40, time=96),
#    Message('note_off', channel=3, note=64, velocity=0, time=48),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=61, velocity=0, time=0),
#    Message('note_on', channel=4, note=62, velocity=56, time=0),
#    Message('note_off', channel=5, note=45, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=41, time=48),
#    Message('control_change', channel=2, control=11, value=42, time=96),
#    Message('control_change', channel=2, control=11, value=43, time=96),
#    Message('control_change', channel=2, control=11, value=44, time=96),
#    Message('control_change', channel=2, control=11, value=45, time=96),
#    Message('control_change', channel=2, control=11, value=46, time=96),
#    Message('control_change', channel=2, control=11, value=47, time=96),
#    Message('control_change', channel=2, control=11, value=48, time=96),
#    Message('control_change', channel=2, control=11, value=49, time=96),
#    Message('control_change', channel=2, control=11, value=50, time=96),
#    Message('control_change', channel=2, control=11, value=51, time=96),
#    Message('control_change', channel=2, control=11, value=52, time=96),
#    Message('control_change', channel=2, control=11, value=53, time=144),
#    Message('control_change', channel=2, control=11, value=54, time=48),
#    Message('control_change', channel=2, control=11, value=55, time=96),
#    Message('note_off', channel=3, note=65, velocity=0, time=48),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=62, velocity=0, time=0),
#    Message('note_on', channel=4, note=62, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=50, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=56, time=48),
#    Message('control_change', channel=2, control=11, value=57, time=96),
#    Message('control_change', channel=2, control=11, value=58, time=96),
#    Message('control_change', channel=2, control=11, value=59, time=144),
#    Message('control_change', channel=2, control=11, value=60, time=48),
#    Message('note_off', channel=3, note=65, velocity=0, time=48),
#    Message('note_on', channel=3, note=65, velocity=56, time=0),
#    Message('note_off', channel=4, note=62, velocity=0, time=0),
#    Message('note_on', channel=4, note=62, velocity=56, time=0),
#    Message('note_off', channel=5, note=50, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=61, time=48),
#    Message('control_change', channel=2, control=11, value=62, time=96),
#    Message('control_change', channel=2, control=11, value=63, time=96),
#    Message('control_change', channel=2, control=11, value=64, time=96),
#    Message('control_change', channel=2, control=11, value=65, time=96),
#    Message('control_change', channel=2, control=11, value=66, time=96),
#    Message('control_change', channel=2, control=11, value=67, time=96),
#    Message('control_change', channel=2, control=11, value=68, time=96),
#    Message('control_change', channel=2, control=11, value=69, time=96),
#    Message('control_change', channel=2, control=11, value=70, time=96),
#    Message('note_off', channel=3, note=65, velocity=0, time=48),
#    Message('note_on', channel=3, note=64, velocity=56, time=0),
#    Message('note_off', channel=4, note=62, velocity=0, time=0),
#    Message('note_on', channel=4, note=60, velocity=56, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=71, time=48),
#    Message('control_change', channel=2, control=11, value=72, time=96),
#    Message('control_change', channel=2, control=11, value=73, time=96),
#    Message('control_change', channel=2, control=11, value=74, time=96),
#    Message('control_change', channel=2, control=11, value=75, time=96),
#    Message('control_change', channel=2, control=11, value=76, time=96),
#    Message('control_change', channel=2, control=11, value=77, time=96),
#    Message('control_change', channel=2, control=11, value=78, time=96),
#    Message('control_change', channel=2, control=11, value=79, time=96),
#    Message('control_change', channel=2, control=11, value=80, time=96),
#    Message('note_off', channel=3, note=64, velocity=0, time=48),
#    Message('note_on', channel=3, note=62, velocity=56, time=0),
#    Message('note_off', channel=4, note=60, velocity=0, time=0),
#    Message('note_on', channel=4, note=58, velocity=56, time=0),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=81, time=48),
#    Message('control_change', channel=2, control=11, value=82, time=96),
#    Message('control_change', channel=2, control=11, value=83, time=96),
#    Message('control_change', channel=2, control=11, value=84, time=96),
#    Message('control_change', channel=2, control=11, value=85, time=96),
#    Message('note_off', channel=3, note=62, velocity=0, time=48),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=58, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=86, time=48),
#    Message('control_change', channel=2, control=11, value=87, time=96),
#    Message('control_change', channel=2, control=11, value=88, time=96),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=56, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=56, time=0),
#    Message('control_change', channel=2, control=11, value=89, time=96),
#    Message('control_change', channel=2, control=11, value=90, time=96),
#    Message('note_off', channel=5, note=41, velocity=0, time=48),
#    Message('note_on', channel=5, note=41, velocity=72, time=0),
#    Message('control_change', channel=2, control=11, value=91, time=48),
#    Message('control_change', channel=2, control=11, value=92, time=96),
#    Message('control_change', channel=2, control=11, value=93, time=96),
#    Message('control_change', channel=2, control=11, value=94, time=96),
#    Message('control_change', channel=2, control=11, value=95, time=96),
#    Message('note_off', channel=5, note=41, velocity=0, time=48),
#    Message('note_on', channel=5, note=40, velocity=72, time=0),
#    Message('control_change', channel=2, control=11, value=96, time=48),
#    Message('control_change', channel=2, control=11, value=97, time=96),
#    Message('control_change', channel=2, control=11, value=98, time=96),
#    Message('control_change', channel=2, control=11, value=99, time=96),
#    Message('control_change', channel=2, control=11, value=100, time=96),
#    Message('note_off', channel=2, note=93, velocity=0, time=48),
#    Message('note_on', channel=2, note=60, velocity=72, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=72, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=72, time=0),
#    Message('note_off', channel=5, note=40, velocity=0, time=0),
#    Message('note_on', channel=5, note=38, velocity=72, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=72, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=72, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=60, velocity=72, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=72, time=0),
#    Message('note_off', channel=2, note=60, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=72, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=72, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=55, velocity=72, time=0),
#    Message('note_off', channel=5, note=38, velocity=0, time=0),
#    Message('note_on', channel=5, note=43, velocity=72, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=72, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=65, velocity=72, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=59, velocity=72, time=0),
#    Message('note_off', channel=3, note=65, velocity=0, time=0),
#    Message('note_on', channel=3, note=59, velocity=72, time=0),
#    Message('note_off', channel=2, note=59, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=72, time=0),
#    Message('note_off', channel=3, note=59, velocity=0, time=0),
#    Message('note_on', channel=3, note=58, velocity=72, time=0),
#    Message('note_off', channel=4, note=55, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=72, time=0),
#    Message('note_off', channel=5, note=43, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=72, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_on', channel=2, note=65, velocity=72, time=0),
#    Message('note_off', channel=3, note=58, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=72, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=72, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=72, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=72, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_on', channel=3, note=60, velocity=72, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_on', channel=4, note=57, velocity=72, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=72, time=0),
#    MetaMessage('set_tempo', tempo=681818, time=1200),
#    Message('note_off', channel=2, note=65, velocity=0, time=0),
#    Message('note_off', channel=3, note=60, velocity=0, time=0),
#    Message('note_off', channel=4, note=57, velocity=0, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=48, velocity=72, time=0),
#    MetaMessage('set_tempo', tempo=714285, time=480),
#    MetaMessage('set_tempo', tempo=740739, time=480),
#    Message('note_off', channel=5, note=48, velocity=0, time=0),
#    Message('note_on', channel=5, note=47, velocity=72, time=0),
#    MetaMessage('set_tempo', tempo=800000, time=480),
#    MetaMessage('set_tempo', tempo=845069, time=480),
#    Message('note_off', channel=5, note=47, velocity=0, time=0),
#    Message('note_on', channel=5, note=46, velocity=72, time=0),
#    MetaMessage('set_tempo', tempo=923075, time=480),
#    Message('note_on', channel=2, note=65, velocity=88, time=0),
#    Message('note_on', channel=3, note=57, velocity=88, time=0),
#    Message('note_on', channel=4, note=53, velocity=88, time=0),
#    Message('note_on', channel=4, note=48, velocity=88, time=0),
#    Message('note_off', channel=5, note=46, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=88, time=0),
#    Message('note_off', channel=2, note=65, velocity=0, time=240),
#    Message('note_on', channel=2, note=65, velocity=88, time=0),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_on', channel=3, note=57, velocity=88, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_off', channel=4, note=48, velocity=0, time=0),
#    Message('note_on', channel=4, note=53, velocity=88, time=0),
#    Message('note_on', channel=4, note=48, velocity=88, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    Message('note_on', channel=5, note=41, velocity=88, time=0),
#    MetaMessage('set_tempo', tempo=1000000, time=1200),
#    Message('note_off', channel=2, note=65, velocity=0, time=480),
#    Message('note_off', channel=3, note=57, velocity=0, time=0),
#    Message('note_off', channel=4, note=53, velocity=0, time=0),
#    Message('note_off', channel=4, note=48, velocity=0, time=0),
#    Message('note_off', channel=5, note=41, velocity=0, time=0),
#    MetaMessage('end_of_track', time=0)])]

# %%
# mensajes en el track 1
for m in mid.tracks[0][:20]:
    print(m)
# Out:
# MetaMessage('track_name', name='Yesterday', time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('key_signature', key='F', time=0)
# MetaMessage('set_tempo', tempo=631577, time=0)
# program_change channel=2 program=40 time=0
# control_change channel=2 control=11 value=100 time=0
# note_on channel=2 note=69 velocity=56 time=0
# control_change channel=2 control=101 value=0 time=0
# control_change channel=2 control=100 value=0 time=0
# control_change channel=2 control=6 value=6 time=0
# program_change channel=3 program=40 time=0
# control_change channel=3 control=11 value=100 time=0
# note_on channel=3 note=65 velocity=56 time=0
# control_change channel=3 control=101 value=0 time=0
# control_change channel=3 control=100 value=0 time=0
# control_change channel=3 control=6 value=6 time=0
# program_change channel=4 program=41 time=0
# control_change channel=4 control=11 value=100 time=0
# note_on channel=4 note=60 velocity=56 time=0
# control_change channel=4 control=101 value=0 time=0

# %%
#[note, note_on(time), note_off(time), channel]
mididict = []
output = []

for i in mid:
    if i.type == 'note_on' or i.type == 'note_off' or i.type == 'time_signature':
        mididict.append(i.dict())
# change time values from delta to relative time.
mem1=0
for i in mididict:
    time = i['time'] + mem1
    i['time'] = time
    mem1 = i['time']
# make every note_on with 0 velocity note_off
    if i['type'] == 'note_on' and i['velocity'] == 0:
        i['type'] = 'note_off'
# put note, starttime, stoptime, as nested list in a list. # format is [type, note, time, channel]
    mem2=[]
    if i['type'] == 'note_on' or i['type'] == 'note_off':
        mem2.append(i['type'])
        mem2.append(i['note'])
        mem2.append(i['time'])
        mem2.append(i['channel'])
        output.append(mem2)
# put timesignatures
    if i['type'] == 'time_signature':
        mem2.append(i['type'])
        mem2.append(i['numerator'])
        mem2.append(i['denominator'])
        mem2.append(i['time'])
        output.append(mem2)
# viewing the midimessages.
for i in output:
    print(i)
print(mid.ticks_per_beat)
# Out:
# ['time_signature', 4, 4, 0]
# ['note_on', 69, 0, 2]
# ['note_on', 65, 0, 3]
# ['note_on', 60, 0, 4]
# ['note_on', 53, 0, 5]
# ['note_off', 69, 2.5263079999999998, 2]
# ['note_on', 69, 2.5263079999999998, 2]
# ['note_off', 65, 2.5263079999999998, 3]
# ['note_on', 62, 2.5263079999999998, 3]
# ['note_off', 60, 2.5263079999999998, 4]
# ['note_on', 58, 2.5263079999999998, 4]
# ['note_off', 53, 2.5263079999999998, 5]
# ['note_on', 52, 2.5263079999999998, 5]
# ['note_off', 69, 3.7894619999999994, 2]
# ['note_on', 64, 3.7894619999999994, 2]
# ['note_off', 62, 3.7894619999999994, 3]
# ['note_on', 61, 3.7894619999999994, 3]
# ['note_off', 58, 3.7894619999999994, 4]
# ['note_on', 57, 3.7894619999999994, 4]
# ['note_off', 52, 3.7894619999999994, 5]
# ['note_on', 45, 3.7894619999999994, 5]
# ['note_off', 64, 5.0526159999999996, 2]
# ['note_on', 65, 5.0526159999999996, 2]
# ['note_off', 61, 5.0526159999999996, 3]
# ['note_on', 62, 5.0526159999999996, 3]
# ['note_off', 57, 5.0526159999999996, 4]
# ['note_on', 57, 5.0526159999999996, 4]
# ['note_off', 45, 5.0526159999999996, 5]
# ['note_on', 50, 5.0526159999999996, 5]
# ['note_off', 65, 6.947346999999999, 2]
# ['note_on', 65, 6.947346999999999, 2]
# ['note_off', 62, 6.947346999999999, 3]
# ['note_on', 64, 6.947346999999999, 3]
# ['note_off', 57, 6.947346999999999, 4]
# ['note_on', 57, 6.947346999999999, 4]
# ['note_off', 50, 6.947346999999999, 5]
# ['note_on', 48, 6.947346999999999, 5]
# ['note_off', 65, 7.578923999999999, 2]
# ['note_on', 65, 7.578923999999999, 2]
# ['note_off', 64, 7.578923999999999, 3]
# ['note_on', 62, 7.578923999999999, 3]
# ['note_off', 57, 7.578923999999999, 4]
# ['note_on', 57, 7.578923999999999, 4]
# ['note_off', 48, 7.578923999999999, 5]
# ['note_on', 46, 7.578923999999999, 5]
# ['note_off', 65, 8.842077999999999, 2]
# ['note_on', 64, 8.842077999999999, 2]
# ['note_off', 62, 8.842077999999999, 3]
# ['note_on', 60, 8.842077999999999, 3]
# ['note_off', 57, 8.842077999999999, 4]
# ['note_on', 55, 8.842077999999999, 4]
# ['note_off', 46, 8.842077999999999, 5]
# ['note_on', 48, 8.842077999999999, 5]
# ['note_off', 64, 10.105231999999999, 2]
# ['note_on', 62, 10.105231999999999, 2]
# ['note_off', 60, 10.105231999999999, 3]
# ['note_on', 58, 10.105231999999999, 3]
# ['note_off', 55, 10.105231999999999, 4]
# ['note_on', 53, 10.105231999999999, 4]
# ['note_off', 48, 10.105231999999999, 5]
# ['note_on', 41, 10.105231999999999, 5]
# ['note_off', 62, 10.736809, 2]
# ['note_on', 60, 10.736809, 2]
# ['note_off', 58, 10.736809, 3]
# ['note_on', 57, 10.736809, 3]
# ['note_off', 60, 11.0525975, 2]
# ['note_on', 60, 11.0525975, 2]
# ['note_off', 57, 11.0525975, 3]
# ['note_on', 57, 11.0525975, 3]
# ['note_off', 41, 11.368386, 5]
# ['note_on', 41, 11.368386, 5]
# ['note_off', 60, 11.999963, 2]
# ['note_on', 60, 11.999963, 2]
# ['note_off', 57, 11.999963, 3]
# ['note_on', 57, 11.999963, 3]
# ['note_off', 53, 11.999963, 4]
# ['note_on', 55, 11.999963, 4]
# ['note_off', 41, 11.999963, 5]
# ['note_on', 40, 11.999963, 5]
# ['note_off', 60, 12.63154, 2]
# ['note_on', 60, 12.63154, 2]
# ['note_off', 57, 12.63154, 3]
# ['note_on', 60, 12.63154, 3]
# ['note_off', 55, 12.63154, 4]
# ['note_on', 53, 12.63154, 4]
# ['note_off', 40, 12.63154, 5]
# ['note_on', 38, 12.63154, 5]
# ['note_off', 60, 13.263117, 2]
# ['note_on', 65, 13.263117, 2]
# ['note_off', 60, 13.263117, 3]
# ['note_on', 65, 13.263117, 3]
# ['note_off', 65, 13.5789055, 2]
# ['note_on', 60, 13.5789055, 2]
# ['note_off', 65, 13.5789055, 3]
# ['note_on', 60, 13.5789055, 3]
# ['note_off', 60, 13.894694, 2]
# ['note_on', 59, 13.894694, 2]
# ['note_off', 60, 13.894694, 3]
# ['note_on', 59, 13.894694, 3]
# ['note_off', 53, 13.894694, 4]
# ['note_on', 55, 13.894694, 4]
# ['note_off', 38, 13.894694, 5]
# ['note_on', 43, 13.894694, 5]
# ['note_off', 59, 14.526271, 2]
# ['note_on', 65, 14.526271, 2]
# ['note_off', 59, 14.526271, 3]
# ['note_on', 65, 14.526271, 3]
# ['note_off', 65, 14.8420595, 2]
# ['note_on', 59, 14.8420595, 2]
# ['note_off', 65, 14.8420595, 3]
# ['note_on', 59, 14.8420595, 3]
# ['note_off', 59, 15.157848, 2]
# ['note_on', 65, 15.157848, 2]
# ['note_off', 59, 15.157848, 3]
# ['note_on', 58, 15.157848, 3]
# ['note_off', 55, 15.157848, 4]
# ['note_on', 53, 15.157848, 4]
# ['note_off', 43, 15.157848, 5]
# ['note_on', 46, 15.157848, 5]
# ['note_off', 65, 15.789425, 2]
# ['note_on', 65, 15.789425, 2]
# ['note_off', 58, 15.789425, 3]
# ['note_on', 60, 15.789425, 3]
# ['note_off', 53, 15.789425, 4]
# ['note_on', 57, 15.789425, 4]
# ['note_off', 46, 15.789425, 5]
# ['note_on', 41, 15.789425, 5]
# ['note_off', 65, 16.105213499999998, 2]
# ['note_on', 65, 16.105213499999998, 2]
# ['note_off', 60, 16.105213499999998, 3]
# ['note_on', 60, 16.105213499999998, 3]
# ['note_off', 57, 16.105213499999998, 4]
# ['note_on', 57, 16.105213499999998, 4]
# ['note_off', 41, 16.105213499999998, 5]
# ['note_on', 41, 16.105213499999998, 5]
# ['note_off', 65, 17.684155999999998, 2]
# ['note_on', 62, 17.684155999999998, 2]
# ['note_off', 60, 17.684155999999998, 3]
# ['note_on', 59, 17.684155999999998, 3]
# ['note_off', 57, 17.684155999999998, 4]
# ['note_on', 55, 17.684155999999998, 4]
# ['note_off', 41, 17.684155999999998, 5]
# ['note_on', 45, 17.684155999999998, 5]
# ['note_off', 62, 18.947309999999998, 2]
# ['note_on', 64, 18.947309999999998, 2]
# ['note_off', 59, 18.947309999999998, 3]
# ['note_on', 61, 18.947309999999998, 3]
# ['note_off', 55, 18.947309999999998, 4]
# ['note_on', 57, 18.947309999999998, 4]
# ['note_off', 64, 20.210463999999998, 2]
# ['note_on', 65, 20.210463999999998, 2]
# ['note_off', 61, 20.210463999999998, 3]
# ['note_on', 62, 20.210463999999998, 3]
# ['note_off', 57, 20.210463999999998, 4]
# ['note_on', 57, 20.210463999999998, 4]
# ['note_off', 45, 20.210463999999998, 5]
# ['note_on', 50, 20.210463999999998, 5]
# ['note_off', 62, 20.842041, 3]
# ['note_on', 64, 20.842041, 3]
# ['note_off', 50, 20.842041, 5]
# ['note_on', 48, 20.842041, 5]
# ['note_off', 64, 21.473618, 3]
# ['note_on', 65, 21.473618, 3]
# ['note_off', 48, 21.473618, 5]
# ['note_on', 46, 21.473618, 5]
# ['note_off', 65, 22.105195, 3]
# ['note_on', 64, 22.105195, 3]
# ['note_off', 46, 22.105195, 5]
# ['note_on', 45, 22.105195, 5]
# ['note_off', 64, 22.4209835, 3]
# ['note_on', 62, 22.4209835, 3]
# ['note_off', 65, 22.736772, 2]
# ['note_on', 64, 22.736772, 2]
# ['note_off', 62, 22.736772, 3]
# ['note_on', 62, 22.736772, 3]
# ['note_off', 57, 22.736772, 4]
# ['note_on', 58, 22.736772, 4]
# ['note_off', 45, 22.736772, 5]
# ['note_on', 43, 22.736772, 5]
# ['note_off', 62, 23.999926, 3]
# ['note_on', 60, 23.999926, 3]
# ['note_off', 43, 23.999926, 5]
# ['note_on', 36, 23.999926, 5]
# ['note_off', 64, 25.26308, 2]
# ['note_on', 60, 25.26308, 2]
# ['note_off', 60, 25.26308, 3]
# ['note_on', 57, 25.26308, 3]
# ['note_off', 58, 25.26308, 4]
# ['note_on', 53, 25.26308, 4]
# ['note_off', 36, 25.26308, 5]
# ['note_on', 41, 25.26308, 5]
# ['note_off', 60, 27.789388, 2]
# ['note_on', 62, 27.789388, 2]
# ['note_off', 57, 27.789388, 3]
# ['note_on', 59, 27.789388, 3]
# ['note_off', 53, 27.789388, 4]
# ['note_on', 55, 27.789388, 4]
# ['note_off', 41, 27.789388, 5]
# ['note_on', 45, 27.789388, 5]
# ['note_off', 62, 29.052542, 2]
# ['note_on', 64, 29.052542, 2]
# ['note_off', 59, 29.052542, 3]
# ['note_on', 61, 29.052542, 3]
# ['note_off', 55, 29.052542, 4]
# ['note_on', 57, 29.052542, 4]
# ['note_off', 64, 30.315696, 2]
# ['note_on', 65, 30.315696, 2]
# ['note_off', 61, 30.315696, 3]
# ['note_on', 62, 30.315696, 3]
# ['note_off', 57, 30.315696, 4]
# ['note_on', 57, 30.315696, 4]
# ['note_off', 45, 30.315696, 5]
# ['note_on', 50, 30.315696, 5]
# ['note_off', 62, 30.947273, 3]
# ['note_on', 64, 30.947273, 3]
# ['note_off', 50, 30.947273, 5]
# ['note_on', 48, 30.947273, 5]
# ['note_off', 64, 31.57885, 3]
# ['note_on', 65, 31.57885, 3]
# ['note_off', 48, 31.57885, 5]
# ['note_on', 46, 31.57885, 5]
# ['note_off', 65, 32.210426999999996, 3]
# ['note_on', 64, 32.210426999999996, 3]
# ['note_off', 46, 32.210426999999996, 5]
# ['note_on', 45, 32.210426999999996, 5]
# ['note_off', 64, 32.52621549999999, 3]
# ['note_on', 62, 32.52621549999999, 3]
# ['note_off', 65, 32.84200399999999, 2]
# ['note_on', 64, 32.84200399999999, 2]
# ['note_off', 62, 32.84200399999999, 3]
# ['note_on', 62, 32.84200399999999, 3]
# ['note_off', 57, 32.84200399999999, 4]
# ['note_on', 58, 32.84200399999999, 4]
# ['note_off', 45, 32.84200399999999, 5]
# ['note_on', 43, 32.84200399999999, 5]
# ['note_off', 62, 34.10515799999999, 3]
# ['note_on', 60, 34.10515799999999, 3]
# ['note_off', 43, 34.10515799999999, 5]
# ['note_on', 36, 34.10515799999999, 5]
# ['note_off', 64, 35.36831199999999, 2]
# ['note_on', 77, 35.36831199999999, 2]
# ['note_off', 60, 35.36831199999999, 3]
# ['note_on', 65, 35.36831199999999, 3]
# ['note_off', 58, 35.36831199999999, 4]
# ['note_on', 57, 35.36831199999999, 4]
# ['note_off', 36, 35.36831199999999, 5]
# ['note_on', 41, 35.36831199999999, 5]
# ['note_off', 77, 35.99988899999999, 2]
# ['note_on', 72, 35.99988899999999, 2]
# ['note_off', 72, 36.63146599999999, 2]
# ['note_on', 70, 36.63146599999999, 2]
# ['note_off', 70, 37.26304299999999, 2]
# ['note_on', 69, 37.26304299999999, 2]
# ['note_off', 69, 37.89461999999999, 2]
# ['note_on', 69, 37.89461999999999, 2]
# ['note_off', 65, 37.89461999999999, 3]
# ['note_on', 65, 37.89461999999999, 3]
# ['note_off', 57, 37.89461999999999, 4]
# ['note_on', 60, 37.89461999999999, 4]
# ['note_off', 41, 37.89461999999999, 5]
# ['note_on', 53, 37.89461999999999, 5]
# ['note_off', 69, 40.42092799999999, 2]
# ['note_on', 69, 40.42092799999999, 2]
# ['note_off', 65, 40.42092799999999, 3]
# ['note_on', 62, 40.42092799999999, 3]
# ['note_off', 60, 40.42092799999999, 4]
# ['note_on', 58, 40.42092799999999, 4]
# ['note_off', 53, 40.42092799999999, 5]
# ['note_on', 52, 40.42092799999999, 5]
# ['note_off', 69, 41.68408199999999, 2]
# ['note_on', 64, 41.68408199999999, 2]
# ['note_off', 62, 41.68408199999999, 3]
# ['note_on', 61, 41.68408199999999, 3]
# ['note_off', 58, 41.68408199999999, 4]
# ['note_on', 57, 41.68408199999999, 4]
# ['note_off', 52, 41.68408199999999, 5]
# ['note_on', 45, 41.68408199999999, 5]
# ['note_off', 64, 42.94723599999999, 2]
# ['note_on', 65, 42.94723599999999, 2]
# ['note_off', 61, 42.94723599999999, 3]
# ['note_on', 62, 42.94723599999999, 3]
# ['note_off', 57, 42.94723599999999, 4]
# ['note_on', 57, 42.94723599999999, 4]
# ['note_off', 45, 42.94723599999999, 5]
# ['note_on', 50, 42.94723599999999, 5]
# ['note_off', 65, 44.84196699999999, 2]
# ['note_on', 65, 44.84196699999999, 2]
# ['note_off', 62, 44.84196699999999, 3]
# ['note_on', 64, 44.84196699999999, 3]
# ['note_off', 57, 44.84196699999999, 4]
# ['note_on', 57, 44.84196699999999, 4]
# ['note_off', 50, 44.84196699999999, 5]
# ['note_on', 48, 44.84196699999999, 5]
# ['note_off', 65, 45.47354399999999, 2]
# ['note_on', 65, 45.47354399999999, 2]
# ['note_off', 64, 45.47354399999999, 3]
# ['note_on', 62, 45.47354399999999, 3]
# ['note_off', 57, 45.47354399999999, 4]
# ['note_on', 57, 45.47354399999999, 4]
# ['note_off', 48, 45.47354399999999, 5]
# ['note_on', 46, 45.47354399999999, 5]
# ['note_off', 65, 46.73669799999999, 2]
# ['note_on', 64, 46.73669799999999, 2]
# ['note_off', 62, 46.73669799999999, 3]
# ['note_on', 60, 46.73669799999999, 3]
# ['note_off', 57, 46.73669799999999, 4]
# ['note_on', 55, 46.73669799999999, 4]
# ['note_off', 46, 46.73669799999999, 5]
# ['note_on', 48, 46.73669799999999, 5]
# ['note_off', 64, 47.99985199999999, 2]
# ['note_on', 62, 47.99985199999999, 2]
# ['note_off', 60, 47.99985199999999, 3]
# ['note_on', 58, 47.99985199999999, 3]
# ['note_off', 55, 47.99985199999999, 4]
# ['note_on', 53, 47.99985199999999, 4]
# ['note_off', 48, 47.99985199999999, 5]
# ['note_on', 41, 47.99985199999999, 5]
# ['note_off', 62, 48.63142899999999, 2]
# ['note_on', 60, 48.63142899999999, 2]
# ['note_off', 58, 48.63142899999999, 3]
# ['note_on', 57, 48.63142899999999, 3]
# ['note_off', 60, 48.94721749999999, 2]
# ['note_on', 60, 48.94721749999999, 2]
# ['note_off', 57, 48.94721749999999, 3]
# ['note_on', 57, 48.94721749999999, 3]
# ['note_off', 41, 49.26300599999998, 5]
# ['note_on', 41, 49.26300599999998, 5]
# ['note_off', 60, 49.89458299999998, 2]
# ['note_on', 60, 49.89458299999998, 2]
# ['note_off', 57, 49.89458299999998, 3]
# ['note_on', 57, 49.89458299999998, 3]
# ['note_off', 53, 49.89458299999998, 4]
# ['note_on', 55, 49.89458299999998, 4]
# ['note_off', 41, 49.89458299999998, 5]
# ['note_on', 40, 49.89458299999998, 5]
# ['note_off', 60, 50.52615999999998, 2]
# ['note_on', 60, 50.52615999999998, 2]
# ['note_off', 57, 50.52615999999998, 3]
# ['note_on', 60, 50.52615999999998, 3]
# ['note_off', 55, 50.52615999999998, 4]
# ['note_on', 53, 50.52615999999998, 4]
# ['note_off', 40, 50.52615999999998, 5]
# ['note_on', 38, 50.52615999999998, 5]
# ['note_off', 60, 51.15773699999998, 2]
# ['note_on', 65, 51.15773699999998, 2]
# ['note_off', 60, 51.15773699999998, 3]
# ['note_on', 65, 51.15773699999998, 3]
# ['note_off', 65, 51.47352549999998, 2]
# ['note_on', 60, 51.47352549999998, 2]
# ['note_off', 65, 51.47352549999998, 3]
# ['note_on', 60, 51.47352549999998, 3]
# ['note_off', 60, 51.789313999999976, 2]
# ['note_on', 59, 51.789313999999976, 2]
# ['note_off', 60, 51.789313999999976, 3]
# ['note_on', 59, 51.789313999999976, 3]
# ['note_off', 53, 51.789313999999976, 4]
# ['note_on', 55, 51.789313999999976, 4]
# ['note_off', 38, 51.789313999999976, 5]
# ['note_on', 43, 51.789313999999976, 5]
# ['note_off', 59, 52.420890999999976, 2]
# ['note_on', 65, 52.420890999999976, 2]
# ['note_off', 59, 52.420890999999976, 3]
# ['note_on', 65, 52.420890999999976, 3]
# ['note_off', 65, 52.73667949999997, 2]
# ['note_on', 59, 52.73667949999997, 2]
# ['note_off', 65, 52.73667949999997, 3]
# ['note_on', 59, 52.73667949999997, 3]
# ['note_off', 59, 53.05246799999997, 2]
# ['note_on', 65, 53.05246799999997, 2]
# ['note_off', 59, 53.05246799999997, 3]
# ['note_on', 58, 53.05246799999997, 3]
# ['note_off', 55, 53.05246799999997, 4]
# ['note_on', 53, 53.05246799999997, 4]
# ['note_off', 43, 53.05246799999997, 5]
# ['note_on', 46, 53.05246799999997, 5]
# ['note_off', 65, 53.68404499999997, 2]
# ['note_on', 65, 53.68404499999997, 2]
# ['note_off', 58, 53.68404499999997, 3]
# ['note_on', 60, 53.68404499999997, 3]
# ['note_off', 53, 53.68404499999997, 4]
# ['note_on', 57, 53.68404499999997, 4]
# ['note_off', 46, 53.68404499999997, 5]
# ['note_on', 41, 53.68404499999997, 5]
# ['note_off', 65, 53.999833499999966, 2]
# ['note_on', 65, 53.999833499999966, 2]
# ['note_off', 60, 53.999833499999966, 3]
# ['note_on', 60, 53.999833499999966, 3]
# ['note_off', 57, 53.999833499999966, 4]
# ['note_on', 57, 53.999833499999966, 4]
# ['note_off', 41, 53.999833499999966, 5]
# ['note_on', 41, 53.999833499999966, 5]
# ['note_off', 65, 55.57877599999996, 2]
# ['note_on', 62, 55.57877599999996, 2]
# ['note_off', 60, 55.57877599999996, 3]
# ['note_on', 59, 55.57877599999996, 3]
# ['note_off', 57, 55.57877599999996, 4]
# ['note_on', 55, 55.57877599999996, 4]
# ['note_off', 41, 55.57877599999996, 5]
# ['note_on', 45, 55.57877599999996, 5]
# ['note_off', 62, 56.84192999999996, 2]
# ['note_on', 64, 56.84192999999996, 2]
# ['note_off', 59, 56.84192999999996, 3]
# ['note_on', 61, 56.84192999999996, 3]
# ['note_off', 55, 56.84192999999996, 4]
# ['note_on', 57, 56.84192999999996, 4]
# ['note_off', 64, 58.10508399999996, 2]
# ['note_on', 65, 58.10508399999996, 2]
# ['note_off', 61, 58.10508399999996, 3]
# ['note_on', 62, 58.10508399999996, 3]
# ['note_off', 57, 58.10508399999996, 4]
# ['note_on', 57, 58.10508399999996, 4]
# ['note_off', 45, 58.10508399999996, 5]
# ['note_on', 50, 58.10508399999996, 5]
# ['note_off', 65, 58.73666099999996, 2]
# ['note_on', 67, 58.73666099999996, 2]
# ['note_off', 62, 58.73666099999996, 3]
# ['note_on', 64, 58.73666099999996, 3]
# ['note_off', 50, 58.73666099999996, 5]
# ['note_on', 48, 58.73666099999996, 5]
# ['note_off', 67, 59.36823799999996, 2]
# ['note_on', 69, 59.36823799999996, 2]
# ['note_off', 64, 59.36823799999996, 3]
# ['note_on', 65, 59.36823799999996, 3]
# ['note_off', 48, 59.36823799999996, 5]
# ['note_on', 46, 59.36823799999996, 5]
# ['note_off', 69, 59.99981499999996, 2]
# ['note_on', 67, 59.99981499999996, 2]
# ['note_off', 65, 59.99981499999996, 3]
# ['note_on', 64, 59.99981499999996, 3]
# ['note_off', 46, 59.99981499999996, 5]
# ['note_on', 45, 59.99981499999996, 5]
# ['note_off', 67, 60.31560349999996, 2]
# ['note_on', 65, 60.31560349999996, 2]
# ['note_off', 64, 60.31560349999996, 3]
# ['note_on', 62, 60.31560349999996, 3]
# ['note_off', 65, 60.631391999999956, 2]
# ['note_on', 67, 60.631391999999956, 2]
# ['note_off', 62, 60.631391999999956, 3]
# ['note_on', 64, 60.631391999999956, 3]
# ['note_off', 57, 60.631391999999956, 4]
# ['note_on', 58, 60.631391999999956, 4]
# ['note_off', 45, 60.631391999999956, 5]
# ['note_on', 43, 60.631391999999956, 5]
# ['note_off', 67, 61.57875749999995, 2]
# ['note_on', 65, 61.57875749999995, 2]
# ['note_off', 64, 61.57875749999995, 3]
# ['note_on', 62, 61.57875749999995, 3]
# ['note_off', 65, 61.89454599999995, 2]
# ['note_on', 64, 61.89454599999995, 2]
# ['note_off', 62, 61.89454599999995, 3]
# ['note_on', 60, 61.89454599999995, 3]
# ['note_off', 58, 61.89454599999995, 4]
# ['note_on', 55, 61.89454599999995, 4]
# ['note_off', 43, 61.89454599999995, 5]
# ['note_on', 36, 61.89454599999995, 5]
# ['note_off', 64, 63.15769999999995, 2]
# ['note_on', 60, 63.15769999999995, 2]
# ['note_off', 60, 63.15769999999995, 3]
# ['note_on', 57, 63.15769999999995, 3]
# ['note_off', 55, 63.15769999999995, 4]
# ['note_on', 53, 63.15769999999995, 4]
# ['note_off', 36, 63.15769999999995, 5]
# ['note_on', 41, 63.15769999999995, 5]
# ['note_off', 41, 63.78927699999995, 5]
# ['note_on', 48, 63.78927699999995, 5]
# ['note_off', 48, 64.34190687499995, 5]
# ['note_on', 50, 64.34190687499995, 5]
# ['note_off', 50, 64.42085399999995, 5]
# ['note_on', 51, 64.42085399999995, 5]
# ['note_off', 51, 64.42743292708329, 5]
# ['note_on', 48, 64.42743292708329, 5]
# ['note_off', 48, 64.74322142708328, 5]
# ['note_on', 46, 64.74322142708328, 5]
# ['note_off', 60, 65.05900992708328, 2]
# ['note_on', 62, 65.05900992708328, 2]
# ['note_off', 57, 65.05900992708328, 3]
# ['note_on', 59, 65.05900992708328, 3]
# ['note_off', 53, 65.05900992708328, 4]
# ['note_on', 55, 65.05900992708328, 4]
# ['note_off', 46, 65.05900992708328, 5]
# ['note_on', 41, 65.05900992708328, 5]
# ['note_off', 62, 66.32216392708328, 2]
# ['note_on', 64, 66.32216392708328, 2]
# ['note_off', 59, 66.32216392708328, 3]
# ['note_on', 61, 66.32216392708328, 3]
# ['note_off', 55, 66.32216392708328, 4]
# ['note_on', 57, 66.32216392708328, 4]
# ['note_off', 64, 67.58531792708328, 2]
# ['note_on', 65, 67.58531792708328, 2]
# ['note_off', 61, 67.58531792708328, 3]
# ['note_on', 62, 67.58531792708328, 3]
# ['note_off', 57, 67.58531792708328, 4]
# ['note_on', 57, 67.58531792708328, 4]
# ['note_off', 41, 67.58531792708328, 5]
# ['note_on', 50, 67.58531792708328, 5]
# ['note_off', 65, 68.21689492708327, 2]
# ['note_on', 67, 68.21689492708327, 2]
# ['note_off', 62, 68.21689492708327, 3]
# ['note_on', 64, 68.21689492708327, 3]
# ['note_off', 50, 68.21689492708327, 5]
# ['note_on', 48, 68.21689492708327, 5]
# ['note_off', 67, 68.84847192708327, 2]
# ['note_on', 69, 68.84847192708327, 2]
# ['note_off', 64, 68.84847192708327, 3]
# ['note_on', 65, 68.84847192708327, 3]
# ['note_off', 48, 68.84847192708327, 5]
# ['note_on', 46, 68.84847192708327, 5]
# ['note_off', 69, 69.48004892708326, 2]
# ['note_on', 67, 69.48004892708326, 2]
# ['note_off', 65, 69.48004892708326, 3]
# ['note_on', 64, 69.48004892708326, 3]
# ['note_off', 46, 69.48004892708326, 5]
# ['note_on', 45, 69.48004892708326, 5]
# ['note_off', 67, 69.79583742708326, 2]
# ['note_on', 65, 69.79583742708326, 2]
# ['note_off', 64, 69.79583742708326, 3]
# ['note_on', 62, 69.79583742708326, 3]
# ['note_off', 65, 70.11162592708325, 2]
# ['note_on', 67, 70.11162592708325, 2]
# ['note_off', 62, 70.11162592708325, 3]
# ['note_on', 64, 70.11162592708325, 3]
# ['note_off', 57, 70.11162592708325, 4]
# ['note_on', 58, 70.11162592708325, 4]
# ['note_off', 45, 70.11162592708325, 5]
# ['note_on', 43, 70.11162592708325, 5]
# ['note_off', 67, 71.05899142708326, 2]
# ['note_on', 65, 71.05899142708326, 2]
# ['note_off', 64, 71.05899142708326, 3]
# ['note_on', 62, 71.05899142708326, 3]
# ['note_off', 65, 71.37477992708325, 2]
# ['note_on', 64, 71.37477992708325, 2]
# ['note_off', 62, 71.37477992708325, 3]
# ['note_on', 60, 71.37477992708325, 3]
# ['note_off', 58, 71.37477992708325, 4]
# ['note_on', 55, 71.37477992708325, 4]
# ['note_off', 43, 71.37477992708325, 5]
# ['note_on', 36, 71.37477992708325, 5]
# ['note_off', 64, 72.63793392708325, 2]
# ['note_on', 77, 72.63793392708325, 2]
# ['note_off', 60, 72.63793392708325, 3]
# ['note_on', 65, 72.63793392708325, 3]
# ['note_off', 55, 72.63793392708325, 4]
# ['note_on', 57, 72.63793392708325, 4]
# ['note_off', 36, 72.63793392708325, 5]
# ['note_on', 41, 72.63793392708325, 5]
# ['note_off', 77, 75.16424192708325, 2]
# ['note_on', 93, 75.16424192708325, 2]
# ['note_off', 65, 75.16424192708325, 3]
# ['note_on', 69, 75.16424192708325, 3]
# ['note_off', 57, 75.16424192708325, 4]
# ['note_on', 60, 75.16424192708325, 4]
# ['note_off', 41, 75.16424192708325, 5]
# ['note_on', 53, 75.16424192708325, 5]
# ['note_off', 69, 75.22739962708326, 3]
# ['note_on', 67, 75.22739962708326, 3]
# ['note_off', 60, 75.22739962708326, 4]
# ['note_on', 59, 75.22739962708326, 4]
# ['note_off', 53, 75.22739962708326, 5]
# ['note_on', 52, 75.22739962708326, 5]
# ['note_off', 67, 75.22739962708326, 3]
# ['note_on', 64, 75.22739962708326, 3]
# ['note_off', 59, 75.22739962708326, 4]
# ['note_on', 61, 75.22739962708326, 4]
# ['note_off', 52, 75.22739962708326, 5]
# ['note_on', 45, 75.22739962708326, 5]
# ['note_off', 64, 75.29055732708326, 3]
# ['note_on', 65, 75.29055732708326, 3]
# ['note_off', 61, 75.29055732708326, 4]
# ['note_on', 62, 75.29055732708326, 4]
# ['note_off', 45, 75.29055732708326, 5]
# ['note_on', 50, 75.29055732708326, 5]
# ['note_off', 65, 75.35371502708327, 3]
# ['note_on', 65, 75.35371502708327, 3]
# ['note_off', 62, 75.35371502708327, 4]
# ['note_on', 62, 75.35371502708327, 4]
# ['note_off', 50, 75.35371502708327, 5]
# ['note_on', 50, 75.35371502708327, 5]
# ['note_off', 65, 75.41687272708327, 3]
# ['note_on', 65, 75.41687272708327, 3]
# ['note_off', 62, 75.41687272708327, 4]
# ['note_on', 62, 75.41687272708327, 4]
# ['note_off', 50, 75.41687272708327, 5]
# ['note_on', 46, 75.41687272708327, 5]
# ['note_off', 65, 75.48003042708328, 3]
# ['note_on', 64, 75.48003042708328, 3]
# ['note_off', 62, 75.48003042708328, 4]
# ['note_on', 60, 75.48003042708328, 4]
# ['note_off', 46, 75.48003042708328, 5]
# ['note_on', 48, 75.48003042708328, 5]
# ['note_off', 64, 75.54318812708328, 3]
# ['note_on', 62, 75.54318812708328, 3]
# ['note_off', 60, 75.54318812708328, 4]
# ['note_on', 58, 75.54318812708328, 4]
# ['note_off', 48, 75.54318812708328, 5]
# ['note_on', 41, 75.54318812708328, 5]
# ['note_off', 62, 75.60634582708329, 3]
# ['note_on', 60, 75.60634582708329, 3]
# ['note_off', 58, 75.60634582708329, 4]
# ['note_on', 57, 75.60634582708329, 4]
# ['note_off', 60, 75.60634582708329, 3]
# ['note_on', 60, 75.60634582708329, 3]
# ['note_off', 57, 75.60634582708329, 4]
# ['note_on', 57, 75.60634582708329, 4]
# ['note_off', 41, 75.6695035270833, 5]
# ['note_on', 41, 75.6695035270833, 5]
# ['note_off', 41, 75.7326612270833, 5]
# ['note_on', 40, 75.7326612270833, 5]
# ['note_off', 93, 75.7958189270833, 2]
# ['note_on', 60, 75.7958189270833, 2]
# ['note_off', 60, 75.7958189270833, 3]
# ['note_on', 60, 75.7958189270833, 3]
# ['note_off', 57, 75.7958189270833, 4]
# ['note_on', 53, 75.7958189270833, 4]
# ['note_off', 40, 75.7958189270833, 5]
# ['note_on', 38, 75.7958189270833, 5]
# ['note_off', 60, 76.4273959270833, 2]
# ['note_on', 65, 76.4273959270833, 2]
# ['note_off', 60, 76.4273959270833, 3]
# ['note_on', 65, 76.4273959270833, 3]
# ['note_off', 65, 76.74318442708329, 2]
# ['note_on', 60, 76.74318442708329, 2]
# ['note_off', 65, 76.74318442708329, 3]
# ['note_on', 60, 76.74318442708329, 3]
# ['note_off', 60, 77.05897292708329, 2]
# ['note_on', 59, 77.05897292708329, 2]
# ['note_off', 60, 77.05897292708329, 3]
# ['note_on', 59, 77.05897292708329, 3]
# ['note_off', 53, 77.05897292708329, 4]
# ['note_on', 55, 77.05897292708329, 4]
# ['note_off', 38, 77.05897292708329, 5]
# ['note_on', 43, 77.05897292708329, 5]
# ['note_off', 59, 77.69054992708328, 2]
# ['note_on', 65, 77.69054992708328, 2]
# ['note_off', 59, 77.69054992708328, 3]
# ['note_on', 65, 77.69054992708328, 3]
# ['note_off', 65, 78.00633842708328, 2]
# ['note_on', 59, 78.00633842708328, 2]
# ['note_off', 65, 78.00633842708328, 3]
# ['note_on', 59, 78.00633842708328, 3]
# ['note_off', 59, 78.32212692708327, 2]
# ['note_on', 65, 78.32212692708327, 2]
# ['note_off', 59, 78.32212692708327, 3]
# ['note_on', 58, 78.32212692708327, 3]
# ['note_off', 55, 78.32212692708327, 4]
# ['note_on', 53, 78.32212692708327, 4]
# ['note_off', 43, 78.32212692708327, 5]
# ['note_on', 46, 78.32212692708327, 5]
# ['note_off', 65, 78.95370392708327, 2]
# ['note_on', 65, 78.95370392708327, 2]
# ['note_off', 58, 78.95370392708327, 3]
# ['note_on', 60, 78.95370392708327, 3]
# ['note_off', 53, 78.95370392708327, 4]
# ['note_on', 57, 78.95370392708327, 4]
# ['note_off', 46, 78.95370392708327, 5]
# ['note_on', 41, 78.95370392708327, 5]
# ['note_off', 65, 79.26949242708326, 2]
# ['note_on', 65, 79.26949242708326, 2]
# ['note_off', 60, 79.26949242708326, 3]
# ['note_on', 60, 79.26949242708326, 3]
# ['note_off', 57, 79.26949242708326, 4]
# ['note_on', 57, 79.26949242708326, 4]
# ['note_off', 41, 79.26949242708326, 5]
# ['note_on', 41, 79.26949242708326, 5]
# ['note_off', 65, 79.26949242708326, 2]
# ['note_off', 60, 79.26949242708326, 3]
# ['note_off', 57, 79.26949242708326, 4]
# ['note_off', 41, 79.26949242708326, 5]
# ['note_on', 48, 79.26949242708326, 5]
# ['note_off', 48, 79.26949242708326, 5]
# ['note_on', 47, 79.26949242708326, 5]
# ['note_off', 47, 79.26949242708326, 5]
# ['note_on', 46, 79.26949242708326, 5]
# ['note_on', 65, 79.26949242708326, 2]
# ['note_on', 57, 79.26949242708326, 3]
# ['note_on', 53, 79.26949242708326, 4]
# ['note_on', 48, 79.26949242708326, 4]
# ['note_off', 46, 79.26949242708326, 5]
# ['note_on', 41, 79.26949242708326, 5]
# ['note_off', 65, 79.73102992708327, 2]
# ['note_on', 65, 79.73102992708327, 2]
# ['note_off', 57, 79.73102992708327, 3]
# ['note_on', 57, 79.73102992708327, 3]
# ['note_off', 53, 79.73102992708327, 4]
# ['note_off', 48, 79.73102992708327, 4]
# ['note_on', 53, 79.73102992708327, 4]
# ['note_on', 48, 79.73102992708327, 4]
# ['note_off', 41, 79.73102992708327, 5]
# ['note_on', 41, 79.73102992708327, 5]
# ['note_off', 65, 80.73102992708327, 2]
# ['note_off', 57, 80.73102992708327, 3]
# ['note_off', 53, 80.73102992708327, 4]
# ['note_off', 48, 80.73102992708327, 4]
# ['note_off', 41, 80.73102992708327, 5]
# 480

# %%
import pandas as pd
# formato [note, note_on(time), note_off(time), channel]
df_output_list = pd.DataFrame(output, columns=['message', 'note_on', 'time', 'channel'])
df_output_list
# Out:
#             message  note_on      time  channel
# 0    time_signature        4   4.00000        0
# 1           note_on       69   0.00000        2
# 2           note_on       65   0.00000        3
# 3           note_on       60   0.00000        4
# 4           note_on       53   0.00000        5
# ..              ...      ...       ...      ...
# 688        note_off       65  80.73103        2
# 689        note_off       57  80.73103        3
# 690        note_off       53  80.73103        4
# 691        note_off       48  80.73103        4
# 692        note_off       41  80.73103        5
#
# [693 rows x 4 columns]

# %%
# importing required packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = df_output_list

# draw jointplot with
# hex kind
sns.jointplot(x = "time", y = "note_on", hue = "channel", data = data)
# show the plot
plt.show()

# This code is contributed
# by Deepanshu Rustagi.

# %%
# crear el index 'message' de df_output_list
df_midi_onetrack = df_output_list.set_index('message')
df_midi_onetrack
# Out:
#                 note_on      time  channel
# message
# time_signature        4   4.00000        0
# note_on              69   0.00000        2
# note_on              65   0.00000        3
# note_on              60   0.00000        4
# note_on              53   0.00000        5
# ...                 ...       ...      ...
# note_off             65  80.73103        2
# note_off             57  80.73103        3
# note_off             53  80.73103        4
# note_off             48  80.73103        4
# note_off             41  80.73103        5
#
# [693 rows x 3 columns]

# %%
df_midi_onetrack_noton = df_midi_onetrack.loc['note_on']
df_midi_onetrack_noton
df_midi_onetrack_notoff = df_midi_onetrack.loc['note_off']
df_midi_onetrack_notoff
# Out:
#           note_on       time  channel
# message
# note_off       69   2.526308        2
# note_off       65   2.526308        3
# note_off       60   2.526308        4
# note_off       53   2.526308        5
# note_off       69   3.789462        2
# ...           ...        ...      ...
# note_off       65  80.731030        2
# note_off       57  80.731030        3
# note_off       53  80.731030        4
# note_off       48  80.731030        4
# note_off       41  80.731030        5
#
# [346 rows x 3 columns]

# %%
# notas unicas
arr_unique_notes_on = df_midi_onetrack_noton['note_on'].unique()
arr_unique_notes_on
# Out:
# array([69, 65, 60, 53, 62, 58, 52, 64, 61, 57, 45, 50, 48, 46, 55, 41, 40,
#        38, 59, 43, 36, 77, 72, 70, 67, 51, 93, 47])

# %%
arr_unique_notes_off = df_midi_onetrack_notoff['note_on'].unique()
arr_unique_notes_off
# Out:
# array([69, 65, 60, 53, 62, 58, 52, 64, 61, 57, 45, 50, 48, 46, 55, 41, 40,
#        38, 59, 43, 36, 77, 72, 70, 67, 51, 93, 47])

# %%
# prueba en pequeño
y = df_midi_onetrack_notoff[df_midi_onetrack_notoff['note_on'] == 69][['time','channel']].values.tolist()
y
# Out:
# [[2.5263079999999998, 2.0],
#  [3.7894619999999994, 2.0],
#  [37.89461999999999, 2.0],
#  [40.42092799999999, 2.0],
#  [41.68408199999999, 2.0],
#  [59.99981499999996, 2.0],
#  [69.48004892708326, 2.0],
#  [75.22739962708326, 3.0]]

# %%
x = df_midi_onetrack_noton[df_midi_onetrack_noton['note_on'] == 69]['time'].values.tolist()
x
# Out:
# [0.0,
#  2.5263079999999998,
#  37.26304299999999,
#  37.89461999999999,
#  40.42092799999999,
#  59.36823799999996,
#  68.84847192708327,
#  75.16424192708325]

# %%
# len = 346
#print(len(x))
#print(len(y))
ls_times_notes = []
for i in range(len(x)):
  note = 69
  time_s = x[i]
  time_f = y[i][0]
  channel = y[i][1]
  ls_times_notes.append([note, time_s, time_f, channel])
  print(f"{i},{time_s},{time_f}")
df_69_note_ts = pd.DataFrame(ls_times_notes,columns =['note', 'time_s', 'time_f', 'channel'])
#df_69_note_ts.set_index('note', inplace=True)
df_69_note_ts
# Out:
# 0,0.0,2.5263079999999998
# 1,2.5263079999999998,3.7894619999999994
# 2,37.26304299999999,37.89461999999999
# 3,37.89461999999999,40.42092799999999
# 4,40.42092799999999,41.68408199999999
# 5,59.36823799999996,59.99981499999996
# 6,68.84847192708327,69.48004892708326
# 7,75.16424192708325,75.22739962708326
#    note     time_s     time_f  channel
# 0    69   0.000000   2.526308      2.0
# 1    69   2.526308   3.789462      2.0
# 2    69  37.263043  37.894620      2.0
# 3    69  37.894620  40.420928      2.0
# 4    69  40.420928  41.684082      2.0
# 5    69  59.368238  59.999815      2.0
# 6    69  68.848472  69.480049      2.0
# 7    69  75.164242  75.227400      3.0

# %%
# importing required packages
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = df_69_note_ts

# draw jointplot with
# hex kind
sns.jointplot(x = "time_s", y = "time_f", hue = "channel", data = data)
# show the plot
plt.show()

# %%
# los puntos no pueden ser time_s, time_f
# ahora x es el tiempo y y la nota
# valores en Y
mi_y = []
for i in arr_unique_notes_on:
  temp = df_midi_onetrack_notoff[df_midi_onetrack_notoff['note_on'] == i][['time','channel']].values.tolist()
  #print(i, temp, len(temp))
  [ mi_y.append([i] + x) for x in temp ]
  #print(i,temp)
  #if(len(temp) > 0):
    #mi_y += temp
type(mi_y)
mi_y
# Out:
# [[69, 2.5263079999999998, 2.0],
#  [69, 3.7894619999999994, 2.0],
#  [69, 37.89461999999999, 2.0],
#  [69, 40.42092799999999, 2.0],
#  [69, 41.68408199999999, 2.0],
#  [69, 59.99981499999996, 2.0],
#  [69, 69.48004892708326, 2.0],
#  [69, 75.22739962708326, 3.0],
#  [65, 2.5263079999999998, 3.0],
#  [65, 6.947346999999999, 2.0],
#  [65, 7.578923999999999, 2.0],
#  [65, 8.842077999999999, 2.0],
#  [65, 13.5789055, 2.0],
#  [65, 13.5789055, 3.0],
#  [65, 14.8420595, 2.0],
#  [65, 14.8420595, 3.0],
#  [65, 15.789425, 2.0],
#  [65, 16.105213499999998, 2.0],
#  [65, 17.684155999999998, 2.0],
#  [65, 22.105195, 3.0],
#  [65, 22.736772, 2.0],
#  [65, 32.210426999999996, 3.0],
#  [65, 32.84200399999999, 2.0],
#  [65, 37.89461999999999, 3.0],
#  [65, 40.42092799999999, 3.0],
#  [65, 44.84196699999999, 2.0],
#  [65, 45.47354399999999, 2.0],
#  [65, 46.73669799999999, 2.0],
#  [65, 51.47352549999998, 2.0],
#  [65, 51.47352549999998, 3.0],
#  [65, 52.73667949999997, 2.0],
#  [65, 52.73667949999997, 3.0],
#  [65, 53.68404499999997, 2.0],
#  [65, 53.999833499999966, 2.0],
#  [65, 55.57877599999996, 2.0],
#  [65, 58.73666099999996, 2.0],
#  [65, 59.99981499999996, 3.0],
#  [65, 60.631391999999956, 2.0],
#  [65, 61.89454599999995, 2.0],
#  [65, 68.21689492708327, 2.0],
#  [65, 69.48004892708326, 3.0],
#  [65, 70.11162592708325, 2.0],
#  [65, 71.37477992708325, 2.0],
#  [65, 75.16424192708325, 3.0],
#  [65, 75.35371502708327, 3.0],
#  [65, 75.41687272708327, 3.0],
#  [65, 75.48003042708328, 3.0],
#  [65, 76.74318442708329, 2.0],
#  [65, 76.74318442708329, 3.0],
#  [65, 78.00633842708328, 2.0],
#  [65, 78.00633842708328, 3.0],
#  [65, 78.95370392708327, 2.0],
#  [65, 79.26949242708326, 2.0],
#  [65, 79.26949242708326, 2.0],
#  [65, 79.73102992708327, 2.0],
#  [65, 80.73102992708327, 2.0],
#  [60, 2.5263079999999998, 4.0],
#  [60, 10.105231999999999, 3.0],
#  [60, 11.0525975, 2.0],
#  [60, 11.999963, 2.0],
#  [60, 12.63154, 2.0],
#  [60, 13.263117, 2.0],
#  [60, 13.263117, 3.0],
#  [60, 13.894694, 2.0],
#  [60, 13.894694, 3.0],
#  [60, 16.105213499999998, 3.0],
#  [60, 17.684155999999998, 3.0],
#  [60, 25.26308, 3.0],
#  [60, 27.789388, 2.0],
#  [60, 35.36831199999999, 3.0],
#  [60, 40.42092799999999, 4.0],
#  [60, 47.99985199999999, 3.0],
#  [60, 48.94721749999999, 2.0],
#  [60, 49.89458299999998, 2.0],
#  [60, 50.52615999999998, 2.0],
#  [60, 51.15773699999998, 2.0],
#  [60, 51.15773699999998, 3.0],
#  [60, 51.789313999999976, 2.0],
#  [60, 51.789313999999976, 3.0],
#  [60, 53.999833499999966, 3.0],
#  [60, 55.57877599999996, 3.0],
#  [60, 63.15769999999995, 3.0],
#  [60, 65.05900992708328, 2.0],
#  [60, 72.63793392708325, 3.0],
#  [60, 75.22739962708326, 4.0],
#  [60, 75.54318812708328, 4.0],
#  [60, 75.60634582708329, 3.0],
#  [60, 75.7958189270833, 3.0],
#  [60, 76.4273959270833, 2.0],
#  [60, 76.4273959270833, 3.0],
#  [43, 78.32212692708327, 5.0],
#  [36, 25.26308, 5.0],
#  [36, 35.36831199999999, 5.0],
#  [36, 63.15769999999995, 5.0],
#  [36, 72.63793392708325, 5.0],
#  [77, 35.99988899999999, 2.0],
#  [77, 75.16424192708325, 2.0],
#  [72, 36.63146599999999, 2.0],
#  [70, 37.26304299999999, 2.0],
#  [67, 59.36823799999996, 2.0],
#  [67, 60.31560349999996, 2.0],
#  [67, 61.57875749999995, 2.0],
#  [67, 68.84847192708327, 2.0],
#  [67, 69.79583742708326, 2.0],
#  [67, 71.05899142708326, 2.0],
#  [67, 75.22739962708326, 3.0],
#  [51, 64.42743292708329, 5.0],
#  [93, 75.7958189270833, 2.0],
#  [47, 79.26949242708326, 5.0]]

# %%
# valores en X
mi_x = []
for i in arr_unique_notes_on:
  temp = df_midi_onetrack_noton[df_midi_onetrack_noton['note_on'] == i][['time','channel']].values.tolist()
  #print(i, temp, len(temp))
  [ mi_x.append([i] + x) for x in temp ]
  #print(i,temp)
  #if(len(temp) > 0):
  #  mi_x += temp
type(mi_x)
mi_x
# Out:
# [[69, 0.0, 2.0],
#  [69, 2.5263079999999998, 2.0],
#  [69, 37.26304299999999, 2.0],
#  [69, 37.89461999999999, 2.0],
#  [69, 40.42092799999999, 2.0],
#  [69, 59.36823799999996, 2.0],
#  [69, 68.84847192708327, 2.0],
#  [69, 75.16424192708325, 3.0],
#  [65, 0.0, 3.0],
#  [65, 5.0526159999999996, 2.0],
#  [65, 6.947346999999999, 2.0],
#  [65, 7.578923999999999, 2.0],
#  [65, 13.263117, 2.0],
#  [65, 13.263117, 3.0],
#  [65, 14.526271, 2.0],
#  [65, 14.526271, 3.0],
#  [65, 15.157848, 2.0],
#  [65, 15.789425, 2.0],
#  [65, 16.105213499999998, 2.0],
#  [65, 20.210463999999998, 2.0],
#  [65, 21.473618, 3.0],
#  [65, 30.315696, 2.0],
#  [65, 31.57885, 3.0],
#  [65, 35.36831199999999, 3.0],
#  [65, 37.89461999999999, 3.0],
#  [65, 42.94723599999999, 2.0],
#  [65, 44.84196699999999, 2.0],
#  [65, 45.47354399999999, 2.0],
#  [65, 51.15773699999998, 2.0],
#  [65, 51.15773699999998, 3.0],
#  [65, 52.420890999999976, 2.0],
#  [65, 52.420890999999976, 3.0],
#  [65, 53.05246799999997, 2.0],
#  [65, 53.68404499999997, 2.0],
#  [65, 53.999833499999966, 2.0],
#  [65, 58.10508399999996, 2.0],
#  [65, 59.36823799999996, 3.0],
#  [65, 60.31560349999996, 2.0],
#  [65, 61.57875749999995, 2.0],
#  [65, 67.58531792708328, 2.0],
#  [65, 68.84847192708327, 3.0],
#  [65, 69.79583742708326, 2.0],
#  [65, 71.05899142708326, 2.0],
#  [65, 72.63793392708325, 3.0],
#  [65, 75.29055732708326, 3.0],
#  [65, 75.35371502708327, 3.0],
#  [65, 75.41687272708327, 3.0],
#  [65, 76.4273959270833, 2.0],
#  [65, 76.4273959270833, 3.0],
#  [65, 77.69054992708328, 2.0],
#  [65, 77.69054992708328, 3.0],
#  [41, 53.999833499999966, 5.0],
#  [41, 63.15769999999995, 5.0],
#  [41, 65.05900992708328, 5.0],
#  [41, 72.63793392708325, 5.0],
#  [41, 75.54318812708328, 5.0],
#  [41, 75.6695035270833, 5.0],
#  [41, 78.95370392708327, 5.0],
#  [41, 79.26949242708326, 5.0],
#  [41, 79.26949242708326, 5.0],
#  [41, 79.73102992708327, 5.0],
#  [40, 11.999963, 5.0],
#  [40, 49.89458299999998, 5.0],
#  [40, 75.7326612270833, 5.0],
#  [38, 12.63154, 5.0],
#  [38, 50.52615999999998, 5.0],
#  [38, 75.7958189270833, 5.0],
#  [59, 13.894694, 2.0],
#  [59, 13.894694, 3.0],
#  [59, 14.8420595, 2.0],
#  [59, 14.8420595, 3.0],
#  [59, 17.684155999999998, 3.0],
#  [59, 27.789388, 3.0],
#  [59, 51.789313999999976, 2.0],
#  [59, 51.789313999999976, 3.0],
#  [59, 52.73667949999997, 2.0],
#  [59, 52.73667949999997, 3.0],
#  [59, 55.57877599999996, 3.0],
#  [59, 65.05900992708328, 3.0],
#  [59, 75.22739962708326, 4.0],
#  [59, 77.05897292708329, 2.0],
#  [59, 77.05897292708329, 3.0],
#  [59, 78.00633842708328, 2.0],
#  [59, 78.00633842708328, 3.0],
#  [43, 13.894694, 5.0],
#  [43, 22.736772, 5.0],
#  [43, 32.84200399999999, 5.0],
#  [43, 51.789313999999976, 5.0],
#  [43, 60.631391999999956, 5.0],
#  [43, 70.11162592708325, 5.0],
#  [43, 77.05897292708329, 5.0],
#  [36, 23.999926, 5.0],
#  [36, 34.10515799999999, 5.0],
#  [36, 61.89454599999995, 5.0],
#  [36, 71.37477992708325, 5.0],
#  [77, 35.36831199999999, 2.0],
#  [77, 72.63793392708325, 2.0],
#  [72, 35.99988899999999, 2.0],
#  [70, 36.63146599999999, 2.0],
#  [67, 58.73666099999996, 2.0],
#  [67, 59.99981499999996, 2.0],
#  [67, 60.631391999999956, 2.0],
#  [67, 68.21689492708327, 2.0],
#  [67, 69.48004892708326, 2.0],
#  [67, 70.11162592708325, 2.0],
#  [67, 75.22739962708326, 3.0],
#  [51, 64.42085399999995, 5.0],
#  [93, 75.16424192708325, 2.0],
#  [47, 79.26949242708326, 5.0]]

# %%
# generamos el framework X con Y
ls_times_notes_track = []
for i in range(len(mi_x)):
  note = mi_x[i][0]
  time_s = mi_x[i][1]
  time_f = mi_y[i][1]
  channel = mi_y[i][2]
  ls_times_notes_track.append([note, time_s, time_f, channel])
ls_times_notes_track
# Out:
# [[69, 0.0, 2.5263079999999998, 2.0],
#  [69, 2.5263079999999998, 3.7894619999999994, 2.0],
#  [69, 37.26304299999999, 37.89461999999999, 2.0],
#  [69, 37.89461999999999, 40.42092799999999, 2.0],
#  [69, 40.42092799999999, 41.68408199999999, 2.0],
#  [69, 59.36823799999996, 59.99981499999996, 2.0],
#  [69, 68.84847192708327, 69.48004892708326, 2.0],
#  [69, 75.16424192708325, 75.22739962708326, 3.0],
#  [65, 0.0, 2.5263079999999998, 3.0],
#  [67, 69.48004892708326, 69.79583742708326, 2.0],
#  [67, 70.11162592708325, 71.05899142708326, 2.0],
#  [67, 75.22739962708326, 75.22739962708326, 3.0],
#  [51, 64.42085399999995, 64.42743292708329, 5.0],
#  [93, 75.16424192708325, 75.7958189270833, 2.0],
#  [47, 79.26949242708326, 79.26949242708326, 5.0]]

# %%
# vamos a hacer una funcion que genere un numero par de intervalos y los deje en una lista
# recibe star y stop
def genera_ticks (note, ini, fin, channel):
  min_d = 0.0066
  diff = round(fin - ini, 4)
  # generar los ticks
  ticks = int(diff // min_d) # floor division o division entera
  l_ticks = []
  if( fin > ini):
     # generamos los ticks desde ini hasta fin
    for x in range(int(ticks)):
      # los tipos de datos en la list
      l_ticks.append( [str(round(ini + (x * min_d), 4)), str(note), str(channel)])
    l_ticks.append([str(round(fin, 4)), str(note), str(channel)])
  else:
    l_ticks = [str(0), str(note), str(channel)]

  return l_ticks

ls_times_notes_series = []
# la unidad mas pequeña es 0.00658 ~ 0.0066
for x in ls_times_notes_track:
  #print(x[0], x[1], x[2], x[3])
  #print(genera_ticks(x[1], x[2]))
  #ls_times_notes_series.append([genera_ticks(x[1], x[2])])
  ls_times_notes_series += genera_ticks(x[0], x[1], x[2], x[3])
ls_times_notes_series
#np.unique(ls_times_diff)
# Out:
# [['0.0', '69', '2.0'],
#  ['0.0066', '69', '2.0'],
#  ['0.0132', '69', '2.0'],
#  ['0.0198', '69', '2.0'],
#  ['0.0264', '69', '2.0'],
#  ['0.033', '69', '2.0'],
#  ['0.0396', '69', '2.0'],
#  ['0.0462', '69', '2.0'],
#  ['0.0528', '69', '2.0'],
#  ['0.0594', '69', '2.0'],
#  ['0.066', '69', '2.0'],
#  ['0.0726', '69', '2.0'],
#  ['0.0792', '69', '2.0'],
#  ['0.0858', '69', '2.0'],
#  ['0.0924', '69', '2.0'],
#  ['0.099', '69', '2.0'],
#  ['0.1056', '69', '2.0'],
#  ['0.1122', '69', '2.0'],
#  ['0.1188', '69', '2.0'],
#  ['0.1254', '69', '2.0'],
#  ['0.132', '69', '2.0'],
#  ['0.1386', '69', '2.0'],
#  ['0.1452', '69', '2.0'],
#  ['0.1518', '69', '2.0'],
#  ['0.1584', '69', '2.0'],
#  ['0.165', '69', '2.0'],
#  ['0.1716', '69', '2.0'],
#  ['0.1782', '69', '2.0'],
#  ['0.1848', '69', '2.0'],
#  ['0.1914', '69', '2.0'],
#  ['0.198', '69', '2.0'],
#  ['0.2046', '69', '2.0'],
#  ['0.2112', '69', '2.0'],
#  ['0.2178', '69', '2.0'],
#  ['0.2244', '69', '2.0'],
#  ['0.231', '69', '2.0'],
#  ['0.2376', '69', '2.0'],
#  ['0.2442', '69', '2.0'],
#  ['0.2508', '69', '2.0'],
#  ['0.2574', '69', '2.0'],
#  ['0.264', '69', '2.0'],
#  ['0.2706', '69', '2.0'],
#  ['0.2772', '69', '2.0'],
#  ['0.2838', '69', '2.0'],
#  ['0.2904', '69', '2.0'],
#  ['0.297', '69', '2.0'],
#  ['0.3036', '69', '2.0'],
#  ['0.3102', '69', '2.0'],
#  ['0.3168', '69', '2.0'],
#  ['0.3234', '69', '2.0'],
#  ['0.33', '69', '2.0'],
#  ['0.3366', '69', '2.0'],
#  ['0.3432', '69', '2.0'],
#  ['0.3498', '69', '2.0'],
#  ['0.3564', '69', '2.0'],
#  ['0.363', '69', '2.0'],
#  ['0.3696', '69', '2.0'],
#  ['0.3762', '69', '2.0'],
#  ['0.3828', '69', '2.0'],
#  ['0.3894', '69', '2.0'],
#  ['0.396', '69', '2.0'],
#  ['0.4026', '69', '2.0'],
#  ['0.4092', '69', '2.0'],
#  ['0.4158', '69', '2.0'],
#  ['0.4224', '69', '2.0'],
#  ['0.429', '69', '2.0'],
#  ['0.4356', '69', '2.0'],
#  ['0.4422', '69', '2.0'],
#  ['0.4488', '69', '2.0'],
#  ['0.4554', '69', '2.0'],
#  ['0.462', '69', '2.0'],
#  ['0.4686', '69', '2.0'],
#  ['0.4752', '69', '2.0'],
#  ['0.4818', '69', '2.0'],
#  ['0.4884', '69', '2.0'],
#  ['0.495', '69', '2.0'],
#  ['0.5016', '69', '2.0'],
#  ['0.5082', '69', '2.0'],
#  ['0.5148', '69', '2.0'],
#  ['0.5214', '69', '2.0'],
#  ['0.528', '69', '2.0'],
#  ['0.5346', '69', '2.0'],
#  ['0.5412', '69', '2.0'],
#  ['0.5478', '69', '2.0'],
#  ['0.5544', '69', '2.0'],
#  ['0.561', '69', '2.0'],
#  ['0.5676', '69', '2.0'],
#  ['0.5742', '69', '2.0'],
#  ['0.5808', '69', '2.0'],
#  ['0.5874', '69', '2.0'],
#  ['0.594', '69', '2.0'],
#  ['0.6006', '69', '2.0'],
#  ['0.6072', '69', '2.0'],
#  ['0.6138', '69', '2.0'],
#  ['0.6204', '69', '2.0'],
#  ['0.627', '69', '2.0'],
#  ['0.6336', '69', '2.0'],
#  ['0.6402', '69', '2.0'],
#  ['0.6468', '69', '2.0'],
#  ['0.6534', '69', '2.0'],
#  ['0.66', '69', '2.0'],
#  ['0.6666', '69', '2.0'],
#  ['0.6732', '69', '2.0'],
#  ['0.6798', '69', '2.0'],
#  ['0.6864', '69', '2.0'],
#  ['0.693', '69', '2.0'],
#  ['0.6996', '69', '2.0'],
#  ['0.7062', '69', '2.0'],
#  ['0.7128', '69', '2.0'],
#  ['0.7194', '69', '2.0'],
#  ['0.726', '69', '2.0'],
#  ['0.7326', '69', '2.0'],
#  ['0.7392', '69', '2.0'],
#  ['0.7458', '69', '2.0'],
#  ['0.7524', '69', '2.0'],
#  ['0.759', '69', '2.0'],
#  ['0.7656', '69', '2.0'],
#  ['0.7722', '69', '2.0'],
#  ['0.7788', '69', '2.0'],
#  ['0.7854', '69', '2.0'],
#  ['0.792', '69', '2.0'],
#  ['0.7986', '69', '2.0'],
#  ['0.8052', '69', '2.0'],
#  ['0.8118', '69', '2.0'],
#  ['0.8184', '69', '2.0'],
#  ['0.825', '69', '2.0'],
#  ['0.8316', '69', '2.0'],
#  ['0.8382', '69', '2.0'],
#  ['0.8448', '69', '2.0'],
#  ['0.8514', '69', '2.0'],
#  ['0.858', '69', '2.0'],
#  ['0.8646', '69', '2.0'],
#  ['0.8712', '69', '2.0'],
#  ['0.8778', '69', '2.0'],
#  ['0.8844', '69', '2.0'],
#  ['0.891', '69', '2.0'],
#  ['0.8976', '69', '2.0'],
#  ['0.9042', '69', '2.0'],
#  ['0.9108', '69', '2.0'],
#  ['0.9174', '69', '2.0'],
#  ['0.924', '69', '2.0'],
#  ['0.9306', '69', '2.0'],
#  ['0.9372', '69', '2.0'],
#  ['0.9438', '69', '2.0'],
#  ['0.9504', '69', '2.0'],
#  ['0.957', '69', '2.0'],
#  ['0.9636', '69', '2.0'],
#  ['0.9702', '69', '2.0'],
#  ['0.9768', '69', '2.0'],
#  ['0.9834', '69', '2.0'],
#  ['0.99', '69', '2.0'],
#  ['0.9966', '69', '2.0'],
#  ['1.0032', '69', '2.0'],
#  ['1.0098', '69', '2.0'],
#  ['1.0164', '69', '2.0'],
#  ['1.023', '69', '2.0'],
#  ['1.0296', '69', '2.0'],
#  ['1.0362', '69', '2.0'],
#  ['1.0428', '69', '2.0'],
#  ['1.0494', '69', '2.0'],
#  ['1.056', '69', '2.0'],
#  ['1.0626', '69', '2.0'],
#  ['1.0692', '69', '2.0'],
#  ['1.0758', '69', '2.0'],
#  ['1.0824', '69', '2.0'],
#  ['1.089', '69', '2.0'],
#  ['1.0956', '69', '2.0'],
#  ['1.1022', '69', '2.0'],
#  ['1.1088', '69', '2.0'],
#  ['1.1154', '69', '2.0'],
#  ['1.122', '69', '2.0'],
#  ['1.1286', '69', '2.0'],
#  ['1.1352', '69', '2.0'],
#  ['1.1418', '69', '2.0'],
#  ['1.1484', '69', '2.0'],
#  ['1.155', '69', '2.0'],
#  ['1.1616', '69', '2.0'],
#  ['1.1682', '69', '2.0'],
#  ['1.1748', '69', '2.0'],
#  ['1.1814', '69', '2.0'],
#  ['1.188', '69', '2.0'],
#  ['1.1946', '69', '2.0'],
#  ['1.2012', '69', '2.0'],
#  ['1.2078', '69', '2.0'],
#  ['1.2144', '69', '2.0'],
#  ['1.221', '69', '2.0'],
#  ['1.2276', '69', '2.0'],
#  ['1.2342', '69', '2.0'],
#  ['1.2408', '69', '2.0'],
#  ['1.2474', '69', '2.0'],
#  ['1.254', '69', '2.0'],
#  ['1.2606', '69', '2.0'],
#  ['1.2672', '69', '2.0'],
#  ['1.2738', '69', '2.0'],
#  ['1.2804', '69', '2.0'],
#  ['1.287', '69', '2.0'],
#  ['1.2936', '69', '2.0'],
#  ['1.3002', '69', '2.0'],
#  ['1.3068', '69', '2.0'],
#  ['1.3134', '69', '2.0'],
#  ['1.32', '69', '2.0'],
#  ['1.3266', '69', '2.0'],
#  ['1.3332', '69', '2.0'],
#  ['1.3398', '69', '2.0'],
#  ['1.3464', '69', '2.0'],
#  ['1.353', '69', '2.0'],
#  ['1.3596', '69', '2.0'],
#  ['1.3662', '69', '2.0'],
#  ['1.3728', '69', '2.0'],
#  ['1.3794', '69', '2.0'],
#  ['1.386', '69', '2.0'],
#  ['1.3926', '69', '2.0'],
#  ['1.3992', '69', '2.0'],
#  ['1.4058', '69', '2.0'],
#  ['1.4124', '69', '2.0'],
#  ['1.419', '69', '2.0'],
#  ['1.4256', '69', '2.0'],
#  ['1.4322', '69', '2.0'],
#  ['1.4388', '69', '2.0'],
#  ['1.4454', '69', '2.0'],
#  ['1.452', '69', '2.0'],
#  ['1.4586', '69', '2.0'],
#  ['1.4652', '69', '2.0'],
#  ['1.4718', '69', '2.0'],
#  ['1.4784', '69', '2.0'],
#  ['1.485', '69', '2.0'],
#  ['1.4916', '69', '2.0'],
#  ['1.4982', '69', '2.0'],
#  ['1.5048', '69', '2.0'],
#  ['1.5114', '69', '2.0'],
#  ['1.518', '69', '2.0'],
#  ['1.5246', '69', '2.0'],
#  ['1.5312', '69', '2.0'],
#  ['1.5378', '69', '2.0'],
#  ['1.5444', '69', '2.0'],
#  ['1.551', '69', '2.0'],
#  ['1.5576', '69', '2.0'],
#  ['1.5642', '69', '2.0'],
#  ['1.5708', '69', '2.0'],
#  ['1.5774', '69', '2.0'],
#  ['1.584', '69', '2.0'],
#  ['1.5906', '69', '2.0'],
#  ['1.5972', '69', '2.0'],
#  ['1.6038', '69', '2.0'],
#  ['1.6104', '69', '2.0'],
#  ['1.617', '69', '2.0'],
#  ['1.6236', '69', '2.0'],
#  ['1.6302', '69', '2.0'],
#  ['1.6368', '69', '2.0'],
#  ['1.6434', '69', '2.0'],
#  ['1.65', '69', '2.0'],
#  ['1.6566', '69', '2.0'],
#  ['1.6632', '69', '2.0'],
#  ['1.6698', '69', '2.0'],
#  ['1.6764', '69', '2.0'],
#  ['1.683', '69', '2.0'],
#  ['1.6896', '69', '2.0'],
#  ['1.6962', '69', '2.0'],
#  ['1.7028', '69', '2.0'],
#  ['1.7094', '69', '2.0'],
#  ['1.716', '69', '2.0'],
#  ['1.7226', '69', '2.0'],
#  ['1.7292', '69', '2.0'],
#  ['1.7358', '69', '2.0'],
#  ['1.7424', '69', '2.0'],
#  ['1.749', '69', '2.0'],
#  ['1.7556', '69', '2.0'],
#  ['1.7622', '69', '2.0'],
#  ['1.7688', '69', '2.0'],
#  ['1.7754', '69', '2.0'],
#  ['1.782', '69', '2.0'],
#  ['1.7886', '69', '2.0'],
#  ['1.7952', '69', '2.0'],
#  ['1.8018', '69', '2.0'],
#  ['1.8084', '69', '2.0'],
#  ['1.815', '69', '2.0'],
#  ['1.8216', '69', '2.0'],
#  ['1.8282', '69', '2.0'],
#  ['1.8348', '69', '2.0'],
#  ['1.8414', '69', '2.0'],
#  ['1.848', '69', '2.0'],
#  ['1.8546', '69', '2.0'],
#  ['1.8612', '69', '2.0'],
#  ['1.8678', '69', '2.0'],
#  ['1.8744', '69', '2.0'],
#  ['1.881', '69', '2.0'],
#  ['1.8876', '69', '2.0'],
#  ['1.8942', '69', '2.0'],
#  ['1.9008', '69', '2.0'],
#  ['1.9074', '69', '2.0'],
#  ['1.914', '69', '2.0'],
#  ['1.9206', '69', '2.0'],
#  ['1.9272', '69', '2.0'],
#  ['1.9338', '69', '2.0'],
#  ['1.9404', '69', '2.0'],
#  ['1.947', '69', '2.0'],
#  ['1.9536', '69', '2.0'],
#  ['1.9602', '69', '2.0'],
#  ['1.9668', '69', '2.0'],
#  ['1.9734', '69', '2.0'],
#  ['1.98', '69', '2.0'],
#  ['1.9866', '69', '2.0'],
#  ['1.9932', '69', '2.0'],
#  ['1.9998', '69', '2.0'],
#  ['2.0064', '69', '2.0'],
#  ['2.013', '69', '2.0'],
#  ['2.0196', '69', '2.0'],
#  ['2.0262', '69', '2.0'],
#  ['2.0328', '69', '2.0'],
#  ['2.0394', '69', '2.0'],
#  ['2.046', '69', '2.0'],
#  ['2.0526', '69', '2.0'],
#  ['2.0592', '69', '2.0'],
#  ['2.0658', '69', '2.0'],
#  ['2.0724', '69', '2.0'],
#  ['2.079', '69', '2.0'],
#  ['2.0856', '69', '2.0'],
#  ['2.0922', '69', '2.0'],
#  ['2.0988', '69', '2.0'],
#  ['2.1054', '69', '2.0'],
#  ['2.112', '69', '2.0'],
#  ['2.1186', '69', '2.0'],
#  ['2.1252', '69', '2.0'],
#  ['2.1318', '69', '2.0'],
#  ['2.1384', '69', '2.0'],
#  ['2.145', '69', '2.0'],
#  ['2.1516', '69', '2.0'],
#  ['2.1582', '69', '2.0'],
#  ['2.1648', '69', '2.0'],
#  ['2.1714', '69', '2.0'],
#  ['2.178', '69', '2.0'],
#  ['2.1846', '69', '2.0'],
#  ['2.1912', '69', '2.0'],
#  ['2.1978', '69', '2.0'],
#  ['2.2044', '69', '2.0'],
#  ['2.211', '69', '2.0'],
#  ['2.2176', '69', '2.0'],
#  ['2.2242', '69', '2.0'],
#  ['2.2308', '69', '2.0'],
#  ['2.2374', '69', '2.0'],
#  ['2.244', '69', '2.0'],
#  ['2.2506', '69', '2.0'],
#  ['2.2572', '69', '2.0'],
#  ['2.2638', '69', '2.0'],
#  ['2.2704', '69', '2.0'],
#  ['2.277', '69', '2.0'],
#  ['2.2836', '69', '2.0'],
#  ['2.2902', '69', '2.0'],
#  ['2.2968', '69', '2.0'],
#  ['2.3034', '69', '2.0'],
#  ['2.31', '69', '2.0'],
#  ['2.3166', '69', '2.0'],
#  ['2.3232', '69', '2.0'],
#  ['2.3298', '69', '2.0'],
#  ['2.3364', '69', '2.0'],
#  ['2.343', '69', '2.0'],
#  ['2.3496', '69', '2.0'],
#  ['2.3562', '69', '2.0'],
#  ['2.3628', '69', '2.0'],
#  ['2.3694', '69', '2.0'],
#  ['2.376', '69', '2.0'],
#  ['2.3826', '69', '2.0'],
#  ['2.3892', '69', '2.0'],
#  ['2.3958', '69', '2.0'],
#  ['2.4024', '69', '2.0'],
#  ['2.409', '69', '2.0'],
#  ['2.4156', '69', '2.0'],
#  ['2.4222', '69', '2.0'],
#  ['2.4288', '69', '2.0'],
#  ['2.4354', '69', '2.0'],
#  ['2.442', '69', '2.0'],
#  ['2.4486', '69', '2.0'],
#  ['2.4552', '69', '2.0'],
#  ['2.4618', '69', '2.0'],
#  ['2.4684', '69', '2.0'],
#  ['2.475', '69', '2.0'],
#  ['2.4816', '69', '2.0'],
#  ['2.4882', '69', '2.0'],
#  ['2.4948', '69', '2.0'],
#  ['2.5014', '69', '2.0'],
#  ['2.508', '69', '2.0'],
#  ['2.5146', '69', '2.0'],
#  ['2.5263', '69', '2.0'],
#  ['2.5263', '69', '2.0'],
#  ['2.5329', '69', '2.0'],
#  ['2.5395', '69', '2.0'],
#  ['2.5461', '69', '2.0'],
#  ['2.5527', '69', '2.0'],
#  ['2.5593', '69', '2.0'],
#  ['2.5659', '69', '2.0'],
#  ['2.5725', '69', '2.0'],
#  ['2.5791', '69', '2.0'],
#  ['2.5857', '69', '2.0'],
#  ['2.5923', '69', '2.0'],
#  ['2.5989', '69', '2.0'],
#  ['2.6055', '69', '2.0'],
#  ['2.6121', '69', '2.0'],
#  ['2.6187', '69', '2.0'],
#  ['2.6253', '69', '2.0'],
#  ['2.6319', '69', '2.0'],
#  ['2.6385', '69', '2.0'],
#  ['2.6451', '69', '2.0'],
#  ['2.6517', '69', '2.0'],
#  ['2.6583', '69', '2.0'],
#  ['2.6649', '69', '2.0'],
#  ['2.6715', '69', '2.0'],
#  ['2.6781', '69', '2.0'],
#  ['2.6847', '69', '2.0'],
#  ['2.6913', '69', '2.0'],
#  ['2.6979', '69', '2.0'],
#  ['2.7045', '69', '2.0'],
#  ['2.7111', '69', '2.0'],
#  ['2.7177', '69', '2.0'],
#  ['2.7243', '69', '2.0'],
#  ['2.7309', '69', '2.0'],
#  ['2.7375', '69', '2.0'],
#  ['2.7441', '69', '2.0'],
#  ['2.7507', '69', '2.0'],
#  ['2.7573', '69', '2.0'],
#  ['2.7639', '69', '2.0'],
#  ['2.7705', '69', '2.0'],
#  ['2.7771', '69', '2.0'],
#  ['2.7837', '69', '2.0'],
#  ['2.7903', '69', '2.0'],
#  ['2.7969', '69', '2.0'],
#  ['2.8035', '69', '2.0'],
#  ['2.8101', '69', '2.0'],
#  ['2.8167', '69', '2.0'],
#  ['2.8233', '69', '2.0'],
#  ['2.8299', '69', '2.0'],
#  ['2.8365', '69', '2.0'],
#  ['2.8431', '69', '2.0'],
#  ['2.8497', '69', '2.0'],
#  ['2.8563', '69', '2.0'],
#  ['2.8629', '69', '2.0'],
#  ['2.8695', '69', '2.0'],
#  ['2.8761', '69', '2.0'],
#  ['2.8827', '69', '2.0'],
#  ['2.8893', '69', '2.0'],
#  ['2.8959', '69', '2.0'],
#  ['2.9025', '69', '2.0'],
#  ['2.9091', '69', '2.0'],
#  ['2.9157', '69', '2.0'],
#  ['2.9223', '69', '2.0'],
#  ['2.9289', '69', '2.0'],
#  ['2.9355', '69', '2.0'],
#  ['2.9421', '69', '2.0'],
#  ['2.9487', '69', '2.0'],
#  ['2.9553', '69', '2.0'],
#  ['2.9619', '69', '2.0'],
#  ['2.9685', '69', '2.0'],
#  ['2.9751', '69', '2.0'],
#  ['2.9817', '69', '2.0'],
#  ['2.9883', '69', '2.0'],
#  ['2.9949', '69', '2.0'],
#  ['3.0015', '69', '2.0'],
#  ['3.0081', '69', '2.0'],
#  ['3.0147', '69', '2.0'],
#  ['3.0213', '69', '2.0'],
#  ['3.0279', '69', '2.0'],
#  ['3.0345', '69', '2.0'],
#  ['3.0411', '69', '2.0'],
#  ['3.0477', '69', '2.0'],
#  ['3.0543', '69', '2.0'],
#  ['3.0609', '69', '2.0'],
#  ['3.0675', '69', '2.0'],
#  ['3.0741', '69', '2.0'],
#  ['3.0807', '69', '2.0'],
#  ['3.0873', '69', '2.0'],
#  ['3.0939', '69', '2.0'],
#  ['3.1005', '69', '2.0'],
#  ['3.1071', '69', '2.0'],
#  ['3.1137', '69', '2.0'],
#  ['3.1203', '69', '2.0'],
#  ['3.1269', '69', '2.0'],
#  ['3.1335', '69', '2.0'],
#  ['3.1401', '69', '2.0'],
#  ['3.1467', '69', '2.0'],
#  ['3.1533', '69', '2.0'],
#  ['3.1599', '69', '2.0'],
#  ['3.1665', '69', '2.0'],
#  ['3.1731', '69', '2.0'],
#  ['3.1797', '69', '2.0'],
#  ['3.1863', '69', '2.0'],
#  ['3.1929', '69', '2.0'],
#  ['3.1995', '69', '2.0'],
#  ['3.2061', '69', '2.0'],
#  ['3.2127', '69', '2.0'],
#  ['3.2193', '69', '2.0'],
#  ['3.2259', '69', '2.0'],
#  ['3.2325', '69', '2.0'],
#  ['3.2391', '69', '2.0'],
#  ['3.2457', '69', '2.0'],
#  ['3.2523', '69', '2.0'],
#  ['3.2589', '69', '2.0'],
#  ['3.2655', '69', '2.0'],
#  ['3.2721', '69', '2.0'],
#  ['3.2787', '69', '2.0'],
#  ['3.2853', '69', '2.0'],
#  ['3.2919', '69', '2.0'],
#  ['3.2985', '69', '2.0'],
#  ['3.3051', '69', '2.0'],
#  ['3.3117', '69', '2.0'],
#  ['3.3183', '69', '2.0'],
#  ['3.3249', '69', '2.0'],
#  ['3.3315', '69', '2.0'],
#  ['3.3381', '69', '2.0'],
#  ['3.3447', '69', '2.0'],
#  ['3.3513', '69', '2.0'],
#  ['3.3579', '69', '2.0'],
#  ['3.3645', '69', '2.0'],
#  ['3.3711', '69', '2.0'],
#  ['3.3777', '69', '2.0'],
#  ['3.3843', '69', '2.0'],
#  ['3.3909', '69', '2.0'],
#  ['3.3975', '69', '2.0'],
#  ['3.4041', '69', '2.0'],
#  ['3.4107', '69', '2.0'],
#  ['3.4173', '69', '2.0'],
#  ['3.4239', '69', '2.0'],
#  ['3.4305', '69', '2.0'],
#  ['3.4371', '69', '2.0'],
#  ['3.4437', '69', '2.0'],
#  ['3.4503', '69', '2.0'],
#  ['3.4569', '69', '2.0'],
#  ['3.4635', '69', '2.0'],
#  ['3.4701', '69', '2.0'],
#  ['3.4767', '69', '2.0'],
#  ['3.4833', '69', '2.0'],
#  ['3.4899', '69', '2.0'],
#  ['3.4965', '69', '2.0'],
#  ['3.5031', '69', '2.0'],
#  ['3.5097', '69', '2.0'],
#  ['3.5163', '69', '2.0'],
#  ['3.5229', '69', '2.0'],
#  ['3.5295', '69', '2.0'],
#  ['3.5361', '69', '2.0'],
#  ['3.5427', '69', '2.0'],
#  ['3.5493', '69', '2.0'],
#  ['3.5559', '69', '2.0'],
#  ['3.5625', '69', '2.0'],
#  ['3.5691', '69', '2.0'],
#  ['3.5757', '69', '2.0'],
#  ['3.5823', '69', '2.0'],
#  ['3.5889', '69', '2.0'],
#  ['3.5955', '69', '2.0'],
#  ['3.6021', '69', '2.0'],
#  ['3.6087', '69', '2.0'],
#  ['3.6153', '69', '2.0'],
#  ['3.6219', '69', '2.0'],
#  ['3.6285', '69', '2.0'],
#  ['3.6351', '69', '2.0'],
#  ['3.6417', '69', '2.0'],
#  ['3.6483', '69', '2.0'],
#  ['3.6549', '69', '2.0'],
#  ['3.6615', '69', '2.0'],
#  ['3.6681', '69', '2.0'],
#  ['3.6747', '69', '2.0'],
#  ['3.6813', '69', '2.0'],
#  ['3.6879', '69', '2.0'],
#  ['3.6945', '69', '2.0'],
#  ['3.7011', '69', '2.0'],
#  ['3.7077', '69', '2.0'],
#  ['3.7143', '69', '2.0'],
#  ['3.7209', '69', '2.0'],
#  ['3.7275', '69', '2.0'],
#  ['3.7341', '69', '2.0'],
#  ['3.7407', '69', '2.0'],
#  ['3.7473', '69', '2.0'],
#  ['3.7539', '69', '2.0'],
#  ['3.7605', '69', '2.0'],
#  ['3.7671', '69', '2.0'],
#  ['3.7737', '69', '2.0'],
#  ['3.7803', '69', '2.0'],
#  ['3.7895', '69', '2.0'],
#  ['37.263', '69', '2.0'],
#  ['37.2696', '69', '2.0'],
#  ['37.2762', '69', '2.0'],
#  ['37.2828', '69', '2.0'],
#  ['37.2894', '69', '2.0'],
#  ['37.296', '69', '2.0'],
#  ['37.3026', '69', '2.0'],
#  ['37.3092', '69', '2.0'],
#  ['37.3158', '69', '2.0'],
#  ['37.3224', '69', '2.0'],
#  ['37.329', '69', '2.0'],
#  ['37.3356', '69', '2.0'],
#  ['37.3422', '69', '2.0'],
#  ['37.3488', '69', '2.0'],
#  ['37.3554', '69', '2.0'],
#  ['37.362', '69', '2.0'],
#  ['37.3686', '69', '2.0'],
#  ['37.3752', '69', '2.0'],
#  ['37.3818', '69', '2.0'],
#  ['37.3884', '69', '2.0'],
#  ['37.395', '69', '2.0'],
#  ['37.4016', '69', '2.0'],
#  ['37.4082', '69', '2.0'],
#  ['37.4148', '69', '2.0'],
#  ['37.4214', '69', '2.0'],
#  ['37.428', '69', '2.0'],
#  ['37.4346', '69', '2.0'],
#  ['37.4412', '69', '2.0'],
#  ['37.4478', '69', '2.0'],
#  ['37.4544', '69', '2.0'],
#  ['37.461', '69', '2.0'],
#  ['37.4676', '69', '2.0'],
#  ['37.4742', '69', '2.0'],
#  ['37.4808', '69', '2.0'],
#  ['37.4874', '69', '2.0'],
#  ['37.494', '69', '2.0'],
#  ['37.5006', '69', '2.0'],
#  ['37.5072', '69', '2.0'],
#  ['37.5138', '69', '2.0'],
#  ['37.5204', '69', '2.0'],
#  ['37.527', '69', '2.0'],
#  ['37.5336', '69', '2.0'],
#  ['37.5402', '69', '2.0'],
#  ['37.5468', '69', '2.0'],
#  ['37.5534', '69', '2.0'],
#  ['37.56', '69', '2.0'],
#  ['37.5666', '69', '2.0'],
#  ['37.5732', '69', '2.0'],
#  ['37.5798', '69', '2.0'],
#  ['37.5864', '69', '2.0'],
#  ['37.593', '69', '2.0'],
#  ['37.5996', '69', '2.0'],
#  ['37.6062', '69', '2.0'],
#  ['37.6128', '69', '2.0'],
#  ['37.6194', '69', '2.0'],
#  ['37.626', '69', '2.0'],
#  ['37.6326', '69', '2.0'],
#  ['37.6392', '69', '2.0'],
#  ['37.6458', '69', '2.0'],
#  ['37.6524', '69', '2.0'],
#  ['37.659', '69', '2.0'],
#  ['37.6656', '69', '2.0'],
#  ['37.6722', '69', '2.0'],
#  ['37.6788', '69', '2.0'],
#  ['37.6854', '69', '2.0'],
#  ['37.692', '69', '2.0'],
#  ['37.6986', '69', '2.0'],
#  ['37.7052', '69', '2.0'],
#  ['37.7118', '69', '2.0'],
#  ['37.7184', '69', '2.0'],
#  ['37.725', '69', '2.0'],
#  ['37.7316', '69', '2.0'],
#  ['37.7382', '69', '2.0'],
#  ['37.7448', '69', '2.0'],
#  ['37.7514', '69', '2.0'],
#  ['37.758', '69', '2.0'],
#  ['37.7646', '69', '2.0'],
#  ['37.7712', '69', '2.0'],
#  ['37.7778', '69', '2.0'],
#  ['37.7844', '69', '2.0'],
#  ['37.791', '69', '2.0'],
#  ['37.7976', '69', '2.0'],
#  ['37.8042', '69', '2.0'],
#  ['37.8108', '69', '2.0'],
#  ['37.8174', '69', '2.0'],
#  ['37.824', '69', '2.0'],
#  ['37.8306', '69', '2.0'],
#  ['37.8372', '69', '2.0'],
#  ['37.8438', '69', '2.0'],
#  ['37.8504', '69', '2.0'],
#  ['37.857', '69', '2.0'],
#  ['37.8636', '69', '2.0'],
#  ['37.8702', '69', '2.0'],
#  ['37.8768', '69', '2.0'],
#  ['37.8834', '69', '2.0'],
#  ['37.8946', '69', '2.0'],
#  ['37.8946', '69', '2.0'],
#  ['37.9012', '69', '2.0'],
#  ['37.9078', '69', '2.0'],
#  ['37.9144', '69', '2.0'],
#  ['37.921', '69', '2.0'],
#  ['37.9276', '69', '2.0'],
#  ['37.9342', '69', '2.0'],
#  ['37.9408', '69', '2.0'],
#  ['37.9474', '69', '2.0'],
#  ['37.954', '69', '2.0'],
#  ['37.9606', '69', '2.0'],
#  ['37.9672', '69', '2.0'],
#  ['37.9738', '69', '2.0'],
#  ['37.9804', '69', '2.0'],
#  ['37.987', '69', '2.0'],
#  ['37.9936', '69', '2.0'],
#  ['38.0002', '69', '2.0'],
#  ['38.0068', '69', '2.0'],
#  ['38.0134', '69', '2.0'],
#  ['38.02', '69', '2.0'],
#  ['38.0266', '69', '2.0'],
#  ['38.0332', '69', '2.0'],
#  ['38.0398', '69', '2.0'],
#  ['38.0464', '69', '2.0'],
#  ['38.053', '69', '2.0'],
#  ['38.0596', '69', '2.0'],
#  ['38.0662', '69', '2.0'],
#  ['38.0728', '69', '2.0'],
#  ['38.0794', '69', '2.0'],
#  ['38.086', '69', '2.0'],
#  ['38.0926', '69', '2.0'],
#  ['38.0992', '69', '2.0'],
#  ['38.1058', '69', '2.0'],
#  ['38.1124', '69', '2.0'],
#  ['38.119', '69', '2.0'],
#  ['38.1256', '69', '2.0'],
#  ['38.1322', '69', '2.0'],
#  ['38.1388', '69', '2.0'],
#  ['38.1454', '69', '2.0'],
#  ['38.152', '69', '2.0'],
#  ['38.1586', '69', '2.0'],
#  ['38.1652', '69', '2.0'],
#  ['38.1718', '69', '2.0'],
#  ['38.1784', '69', '2.0'],
#  ['38.185', '69', '2.0'],
#  ['38.1916', '69', '2.0'],
#  ['38.1982', '69', '2.0'],
#  ['38.2048', '69', '2.0'],
#  ['38.2114', '69', '2.0'],
#  ['38.218', '69', '2.0'],
#  ['38.2246', '69', '2.0'],
#  ['38.2312', '69', '2.0'],
#  ['38.2378', '69', '2.0'],
#  ['38.2444', '69', '2.0'],
#  ['38.251', '69', '2.0'],
#  ['38.2576', '69', '2.0'],
#  ['38.2642', '69', '2.0'],
#  ['38.2708', '69', '2.0'],
#  ['38.2774', '69', '2.0'],
#  ['38.284', '69', '2.0'],
#  ['38.2906', '69', '2.0'],
#  ['38.2972', '69', '2.0'],
#  ['38.3038', '69', '2.0'],
#  ['38.3104', '69', '2.0'],
#  ['38.317', '69', '2.0'],
#  ['38.3236', '69', '2.0'],
#  ['38.3302', '69', '2.0'],
#  ['38.3368', '69', '2.0'],
#  ['38.3434', '69', '2.0'],
#  ['38.35', '69', '2.0'],
#  ['38.3566', '69', '2.0'],
#  ['38.3632', '69', '2.0'],
#  ['38.3698', '69', '2.0'],
#  ['38.3764', '69', '2.0'],
#  ['38.383', '69', '2.0'],
#  ['38.3896', '69', '2.0'],
#  ['38.3962', '69', '2.0'],
#  ['38.4028', '69', '2.0'],
#  ['38.4094', '69', '2.0'],
#  ['38.416', '69', '2.0'],
#  ['38.4226', '69', '2.0'],
#  ['38.4292', '69', '2.0'],
#  ['38.4358', '69', '2.0'],
#  ['38.4424', '69', '2.0'],
#  ['38.449', '69', '2.0'],
#  ['38.4556', '69', '2.0'],
#  ['38.4622', '69', '2.0'],
#  ['38.4688', '69', '2.0'],
#  ['38.4754', '69', '2.0'],
#  ['38.482', '69', '2.0'],
#  ['38.4886', '69', '2.0'],
#  ['38.4952', '69', '2.0'],
#  ['38.5018', '69', '2.0'],
#  ['38.5084', '69', '2.0'],
#  ['38.515', '69', '2.0'],
#  ['38.5216', '69', '2.0'],
#  ['38.5282', '69', '2.0'],
#  ['38.5348', '69', '2.0'],
#  ['38.5414', '69', '2.0'],
#  ['38.548', '69', '2.0'],
#  ['38.5546', '69', '2.0'],
#  ['38.5612', '69', '2.0'],
#  ['38.5678', '69', '2.0'],
#  ['38.5744', '69', '2.0'],
#  ['38.581', '69', '2.0'],
#  ['38.5876', '69', '2.0'],
#  ['38.5942', '69', '2.0'],
#  ['38.6008', '69', '2.0'],
#  ['38.6074', '69', '2.0'],
#  ['38.614', '69', '2.0'],
#  ['38.6206', '69', '2.0'],
#  ['38.6272', '69', '2.0'],
#  ['38.6338', '69', '2.0'],
#  ['38.6404', '69', '2.0'],
#  ['38.647', '69', '2.0'],
#  ['38.6536', '69', '2.0'],
#  ['38.6602', '69', '2.0'],
#  ['38.6668', '69', '2.0'],
#  ['38.6734', '69', '2.0'],
#  ['38.68', '69', '2.0'],
#  ['38.6866', '69', '2.0'],
#  ['38.6932', '69', '2.0'],
#  ['38.6998', '69', '2.0'],
#  ['38.7064', '69', '2.0'],
#  ['38.713', '69', '2.0'],
#  ['38.7196', '69', '2.0'],
#  ['38.7262', '69', '2.0'],
#  ['38.7328', '69', '2.0'],
#  ['38.7394', '69', '2.0'],
#  ['38.746', '69', '2.0'],
#  ['38.7526', '69', '2.0'],
#  ['38.7592', '69', '2.0'],
#  ['38.7658', '69', '2.0'],
#  ['38.7724', '69', '2.0'],
#  ['38.779', '69', '2.0'],
#  ['38.7856', '69', '2.0'],
#  ['38.7922', '69', '2.0'],
#  ['38.7988', '69', '2.0'],
#  ['38.8054', '69', '2.0'],
#  ['38.812', '69', '2.0'],
#  ['38.8186', '69', '2.0'],
#  ['38.8252', '69', '2.0'],
#  ['38.8318', '69', '2.0'],
#  ['38.8384', '69', '2.0'],
#  ['38.845', '69', '2.0'],
#  ['38.8516', '69', '2.0'],
#  ['38.8582', '69', '2.0'],
#  ['38.8648', '69', '2.0'],
#  ['38.8714', '69', '2.0'],
#  ['38.878', '69', '2.0'],
#  ['38.8846', '69', '2.0'],
#  ['38.8912', '69', '2.0'],
#  ['38.8978', '69', '2.0'],
#  ['38.9044', '69', '2.0'],
#  ['38.911', '69', '2.0'],
#  ['38.9176', '69', '2.0'],
#  ['38.9242', '69', '2.0'],
#  ['38.9308', '69', '2.0'],
#  ['38.9374', '69', '2.0'],
#  ['38.944', '69', '2.0'],
#  ['38.9506', '69', '2.0'],
#  ['38.9572', '69', '2.0'],
#  ['38.9638', '69', '2.0'],
#  ['38.9704', '69', '2.0'],
#  ['38.977', '69', '2.0'],
#  ['38.9836', '69', '2.0'],
#  ['38.9902', '69', '2.0'],
#  ['38.9968', '69', '2.0'],
#  ['39.0034', '69', '2.0'],
#  ['39.01', '69', '2.0'],
#  ['39.0166', '69', '2.0'],
#  ['39.0232', '69', '2.0'],
#  ['39.0298', '69', '2.0'],
#  ['39.0364', '69', '2.0'],
#  ['39.043', '69', '2.0'],
#  ['39.0496', '69', '2.0'],
#  ['39.0562', '69', '2.0'],
#  ['39.0628', '69', '2.0'],
#  ['39.0694', '69', '2.0'],
#  ['39.076', '69', '2.0'],
#  ['39.0826', '69', '2.0'],
#  ['39.0892', '69', '2.0'],
#  ['39.0958', '69', '2.0'],
#  ['39.1024', '69', '2.0'],
#  ['39.109', '69', '2.0'],
#  ['39.1156', '69', '2.0'],
#  ['39.1222', '69', '2.0'],
#  ['39.1288', '69', '2.0'],
#  ['39.1354', '69', '2.0'],
#  ['39.142', '69', '2.0'],
#  ['39.1486', '69', '2.0'],
#  ['39.1552', '69', '2.0'],
#  ['39.1618', '69', '2.0'],
#  ['39.1684', '69', '2.0'],
#  ['39.175', '69', '2.0'],
#  ['39.1816', '69', '2.0'],
#  ['39.1882', '69', '2.0'],
#  ['39.1948', '69', '2.0'],
#  ['39.2014', '69', '2.0'],
#  ['39.208', '69', '2.0'],
#  ['39.2146', '69', '2.0'],
#  ['39.2212', '69', '2.0'],
#  ['39.2278', '69', '2.0'],
#  ['39.2344', '69', '2.0'],
#  ['39.241', '69', '2.0'],
#  ['39.2476', '69', '2.0'],
#  ['39.2542', '69', '2.0'],
#  ['39.2608', '69', '2.0'],
#  ['39.2674', '69', '2.0'],
#  ['39.274', '69', '2.0'],
#  ['39.2806', '69', '2.0'],
#  ['39.2872', '69', '2.0'],
#  ['39.2938', '69', '2.0'],
#  ['39.3004', '69', '2.0'],
#  ['39.307', '69', '2.0'],
#  ['39.3136', '69', '2.0'],
#  ['39.3202', '69', '2.0'],
#  ['39.3268', '69', '2.0'],
#  ['39.3334', '69', '2.0'],
#  ['39.34', '69', '2.0'],
#  ['39.3466', '69', '2.0'],
#  ['39.3532', '69', '2.0'],
#  ['39.3598', '69', '2.0'],
#  ['39.3664', '69', '2.0'],
#  ['39.373', '69', '2.0'],
#  ['39.3796', '69', '2.0'],
#  ['39.3862', '69', '2.0'],
#  ['39.3928', '69', '2.0'],
#  ['39.3994', '69', '2.0'],
#  ['39.406', '69', '2.0'],
#  ['39.4126', '69', '2.0'],
#  ['39.4192', '69', '2.0'],
#  ['39.4258', '69', '2.0'],
#  ['39.4324', '69', '2.0'],
#  ['39.439', '69', '2.0'],
#  ['39.4456', '69', '2.0'],
#  ['39.4522', '69', '2.0'],
#  ['39.4588', '69', '2.0'],
#  ['39.4654', '69', '2.0'],
#  ['39.472', '69', '2.0'],
#  ['39.4786', '69', '2.0'],
#  ['39.4852', '69', '2.0'],
#  ['39.4918', '69', '2.0'],
#  ['39.4984', '69', '2.0'],
#  ['39.505', '69', '2.0'],
#  ['39.5116', '69', '2.0'],
#  ['39.5182', '69', '2.0'],
#  ['39.5248', '69', '2.0'],
#  ['39.5314', '69', '2.0'],
#  ['39.538', '69', '2.0'],
#  ['39.5446', '69', '2.0'],
#  ['39.5512', '69', '2.0'],
#  ['39.5578', '69', '2.0'],
#  ['39.5644', '69', '2.0'],
#  ['39.571', '69', '2.0'],
#  ['39.5776', '69', '2.0'],
#  ['39.5842', '69', '2.0'],
#  ['39.5908', '69', '2.0'],
#  ['39.5974', '69', '2.0'],
#  ['39.604', '69', '2.0'],
#  ['39.6106', '69', '2.0'],
#  ['39.6172', '69', '2.0'],
#  ['39.6238', '69', '2.0'],
#  ['39.6304', '69', '2.0'],
#  ['39.637', '69', '2.0'],
#  ['39.6436', '69', '2.0'],
#  ['39.6502', '69', '2.0'],
#  ['39.6568', '69', '2.0'],
#  ['39.6634', '69', '2.0'],
#  ['39.67', '69', '2.0'],
#  ['39.6766', '69', '2.0'],
#  ['39.6832', '69', '2.0'],
#  ['39.6898', '69', '2.0'],
#  ['39.6964', '69', '2.0'],
#  ['39.703', '69', '2.0'],
#  ['39.7096', '69', '2.0'],
#  ['39.7162', '69', '2.0'],
#  ['39.7228', '69', '2.0'],
#  ['39.7294', '69', '2.0'],
#  ['39.736', '69', '2.0'],
#  ['39.7426', '69', '2.0'],
#  ['39.7492', '69', '2.0'],
#  ['39.7558', '69', '2.0'],
#  ['39.7624', '69', '2.0'],
#  ['39.769', '69', '2.0'],
#  ['39.7756', '69', '2.0'],
#  ['39.7822', '69', '2.0'],
#  ['39.7888', '69', '2.0'],
#  ['39.7954', '69', '2.0'],
#  ['39.802', '69', '2.0'],
#  ['39.8086', '69', '2.0'],
#  ['39.8152', '69', '2.0'],
#  ['39.8218', '69', '2.0'],
#  ['39.8284', '69', '2.0'],
#  ['39.835', '69', '2.0'],
#  ['39.8416', '69', '2.0'],
#  ['39.8482', '69', '2.0'],
#  ['39.8548', '69', '2.0'],
#  ['39.8614', '69', '2.0'],
#  ['39.868', '69', '2.0'],
#  ['39.8746', '69', '2.0'],
#  ['39.8812', '69', '2.0'],
#  ['39.8878', '69', '2.0'],
#  ['39.8944', '69', '2.0'],
#  ['39.901', '69', '2.0'],
#  ['39.9076', '69', '2.0'],
#  ['39.9142', '69', '2.0'],
#  ['39.9208', '69', '2.0'],
#  ['39.9274', '69', '2.0'],
#  ['39.934', '69', '2.0'],
#  ['39.9406', '69', '2.0'],
#  ['39.9472', '69', '2.0'],
#  ['39.9538', '69', '2.0'],
#  ['39.9604', '69', '2.0'],
#  ['39.967', '69', '2.0'],
#  ['39.9736', '69', '2.0'],
#  ['39.9802', '69', '2.0'],
#  ['39.9868', '69', '2.0'],
#  ['39.9934', '69', '2.0'],
#  ['40.0', '69', '2.0'],
#  ['40.0066', '69', '2.0'],
#  ['40.0132', '69', '2.0'],
#  ['40.0198', '69', '2.0'],
#  ['40.0264', '69', '2.0'],
#  ['40.033', '69', '2.0'],
#  ['40.0396', '69', '2.0'],
#  ['40.0462', '69', '2.0'],
#  ['40.0528', '69', '2.0'],
#  ['40.0594', '69', '2.0'],
#  ...]

# %%
type(ls_times_notes_series)
#mi_x = [ x[0] for x in ls_times_notes_series ]
#for tick, note, channel in ls_times_notes_series:
  #print(tick, note, channel)
  #mi_x.append(x[0])
  #mi_y.append(x[1])
#len(mi_x)
df_notes_series = pd.DataFrame(ls_times_notes_series, columns = ['tick', 'note', 'channel'])
df_notes_series
# Out:
#           tick  note channel
# 0          0.0    69     2.0
# 1       0.0066    69     2.0
# 2       0.0132    69     2.0
# 3       0.0198    69     2.0
# 4       0.0264    69     2.0
# ...        ...   ...     ...
# 49317  75.7846    93     2.0
# 49318  75.7958    93     2.0
# 49319        0  None    None
# 49320        4     7    None
# 49321        5     .       0
#
# [49322 rows x 3 columns]

# %%
# importing required packages
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})

# loading dataset
data = df_notes_series

# draw jointplot with
# hex kind
sns.lineplot(x = "tick", y = "note", sizes=(.25, 2.5), hue="channel", data = data)
# show the plot
plt.show()
