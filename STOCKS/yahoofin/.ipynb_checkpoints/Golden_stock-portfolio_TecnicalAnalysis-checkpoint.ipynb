# %%
import datetime
# for Fibonacci
from datetime import timedelta
import plotly.io as pio
pio.renderers.default = 'notebook'  # Usa 'notebook_connected' si no ves nada
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
# for Japanese Candles analysis
import matplotlib.dates as mdates
# for Elliot Wave analysis
from scipy.signal import find_peaks

# %%
def download_stock_data(symbol, start, end):
    """
    Download stock data from yfinance.
    """
    #data = yf.download(symbol, start=start, end=end, auto_adjust=True)
    ticker = yf.Ticker(symbol)
    data = ticker.history(start=start, end=end, auto_adjust=True)

    info = ticker.info

    meta = {
        "Símbolo": symbol,
        "Sector": info.get("sector", "N/A"),
        "Precio actual": info.get("currentPrice"),
        "Rango diario": f"{info.get('dayLow')} - {info.get('dayHigh')}",
        "Rango 52 semanas": f"{info.get('fiftyTwoWeekLow')} - {info.get('fiftyTwoWeekHigh')}",
    }
    # return data
    return data, meta

def calculate_ema(data, period, column='Close'):
    """
    Calculate Exponential Moving Average (EMA) for a given period.
    """
    return data[column].ewm(span=period, adjust=False).mean()

def identify_support_levels(data, window=20):
    """
    Identify potential support levels based on recent lows within a specified window.
    """
    # Calcula los mínimos rodantes
    recent_lows = data['Close'].rolling(window=window).min()

    # Últimos valores no nulos
    last_lows = recent_lows.dropna().iloc[-window:]

    # ⚠️ Si por alguna razón es DataFrame, conviértelo en Serie
    if isinstance(last_lows, pd.DataFrame):
        last_lows = last_lows.squeeze()

    support_levels = last_lows.unique()
    return support_levels

# candles analysis
def candle_ema_analysis(data, short_period_1=144, short_period_2=169, long_period=576):
    """
    Calculate the exponential moving averages (EMAs) for the Vegas channel analysis.
    """
    data['EMA_144'] = calculate_ema(data, 144)
    #data['EMA_144'] = data['Close'].ewm(span=short_period_1, adjust=False).mean()
    data['EMA_169'] = calculate_ema(data, 169)
    #data['EMA_169'] = data['Close'].ewm(span=short_period_2, adjust=False).mean()
    data['EMA_576'] = calculate_ema(data, 576)
    #data['EMA_576'] = data['Close'].ewm(span=long_period, adjust=False).mean()
    return data
# MCA vegas analysis
def vegas_channel_analysis(data):
    """
    Perform Vegas Channel Analysis by calculating the necessary EMAs.
    """
    # Calculate EMAs for the Vegas Tunnel (144 and 169 periods)
    data['EMA_144'] = calculate_ema(data, 144)
    data['EMA_169'] = calculate_ema(data, 169)
    
    # Calculate shorter-term EMAs (12 and 24 periods)
    data['EMA_12'] = calculate_ema(data, 12)
    data['EMA_24'] = calculate_ema(data, 24)
    
    return data
def identify_peaks_and_troughs(prices, distance=5):
    """
    Identifica picos y valles en una serie de precios (1D).
    """
    # Convertimos a array 1D y limpiamos NaN
    prices_clean = pd.to_numeric(prices, errors='coerce').dropna().values

    if prices_clean.ndim != 1:
        raise ValueError("El parámetro 'prices' debe ser un array 1D o una Serie.")

    # Encontrar picos (máximos locales)
    peaks, _ = find_peaks(prices_clean, distance=distance)

    # Encontrar valles (mínimos locales)
    troughs, _ = find_peaks(-prices_clean, distance=distance)

    return peaks, troughs

# %%
def add_fibonacci_levels(ax, data, column='Close', color_map=None):
    """
    Dibuja niveles de retroceso de Fibonacci en el gráfico proporcionado.
    
    Parámetros:
    - ax: objeto Axes de matplotlib.
    - data: DataFrame con datos de precios.
    - column: columna de precios a utilizar (por defecto: 'Close').
    - color_map: diccionario opcional para personalizar los colores por nivel.
    """
    # Asegura que los datos sean válidos
    prices = pd.to_numeric(data[column], errors='coerce').dropna()
    if prices.empty:
        print("❌ No hay datos válidos para calcular niveles de Fibonacci.")
        return

    max_price = prices.max()
    min_price = prices.min()
    diff = max_price - min_price

    levels = {
        '0.0%': max_price,
        '23.6%': max_price - 0.236 * diff,
        '38.2%': max_price - 0.382 * diff,
        '50.0%': max_price - 0.500 * diff,
        '61.8%': max_price - 0.618 * diff,
        '78.6%': max_price - 0.786 * diff,
        '100.0%': min_price,
    }

    # Colores por defecto si no se pasan
    default_colors = {
        '0.0%': 'green',
        '23.6%': 'gold',
        '38.2%': 'orange',
        '50.0%': 'red',
        '61.8%': 'blue',
        '78.6%': 'purple',
        '100.0%': 'gray',
    }

    color_map = color_map or default_colors

    for label, level in levels.items():
        ax.axhline(y=level, linestyle='--', linewidth=1.2,
                   color=color_map.get(label, 'black'),
                   label=f'Fibo {label}: {level:.2f}')
        ax.text(data.index[0], level, f'{label}', fontsize=8,
                color=color_map.get(label, 'black'),
                verticalalignment='bottom')

    ax.legend(loc='lower left', fontsize=8)

# %%
def plot_fibonacci_horizons(data, symbol, buy_date_str, buy_price, column='Close'):
    """
    Traza gráficos de niveles Fibonacci usando tu función `add_fibonacci_levels`,
    para horizontes de 1 a 4 semanas desde la fecha de compra.
    """
    buy_date = pd.to_datetime(buy_date_str)
    fig, axs = plt.subplots(2, 2, figsize=(16, 10), sharey=True)
    axs = axs.flatten()

    for i, weeks in enumerate([1, 2, 3, 4]):
        end_date = buy_date + timedelta(weeks=weeks)
        #window_data = data[(data.index >= buy_date) & (data.index <= end_date)]
        # Asegura que data.index no tenga zona horaria
        index_naive = data.index.tz_localize(None)
        window_data = data[(index_naive >= buy_date) & (index_naive <= end_date)]

        ax = axs[i]
        if window_data.empty:
            ax.set_title(f"{weeks} semanas - Sin datos")
            continue

        ax.plot(window_data.index, window_data[column], label='Precio Cierre', color='black')
        ax.set_title(f'{symbol} - {weeks} semana(s)')
        ax.set_xlabel('Fecha')
        ax.set_ylabel('Precio')
        ax.scatter(buy_date, buy_price, color='red', zorder=5, label=f'Compra: {buy_price:.2f}')

        # Reutiliza tu función para agregar los niveles de Fibonacci
        add_fibonacci_levels(ax, window_data, column=column)

        ax.grid(True)
        ax.legend(loc='upper left', fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
import plotly.graph_objects as go

def plot_fibonacci_interactive(data, symbol, buy_date, buy_price):
    """
    Muestra un gráfico interactivo de precios con niveles Fibonacci, precio de compra,
    y opción de cambio de horizonte a 1, 2, 3 o 4 semanas.
    """
    # Asegura tipo fecha
    data = data.copy()
    data.index = pd.to_datetime(data.index)
    
    # Filtra últimos 4 semanas
    horizons = {
        "1 semana": data.last('7D'),
        "2 semanas": data.last('14D'),
        "3 semanas": data.last('21D'),
        "4 semanas": data.last('28D'),
    }

    fig = go.Figure()

    for name, subset in horizons.items():
        prices = subset['Close']
        if prices.empty:
            continue
        max_price = prices.max()
        min_price = prices.min()
        diff = max_price - min_price

        levels = {
            '0.0%': max_price,
            '23.6%': max_price - 0.236 * diff,
            '38.2%': max_price - 0.382 * diff,
            '50.0%': max_price - 0.500 * diff,
            '61.8%': max_price - 0.618 * diff,
            '78.6%': max_price - 0.786 * diff,
            '100.0%': min_price,
        }

        visible = True if name == "1 semana" else False

        fig.add_trace(go.Scatter(
            x=subset.index,
            y=subset['Close'],
            mode='lines',
            name=f'{symbol} ({name})',
            visible=visible
        ))

        for label, level in levels.items():
            fig.add_hline(
                y=level,
                line_dash="dot",
                line_color='teal',
                annotation_text=f'{label} ({name})',
                visible=visible
            )

    # Precio de compra como punto
    fig.add_trace(go.Scatter(
        x=[buy_date],
        y=[buy_price],
        mode='markers+text',
        name='Precio Compra',
        text=[f'{buy_price:.2f}'],
        textposition='bottom center',
        marker=dict(color='black', size=10, symbol='star'),
    ))

    # Botones interactivos
    buttons = []
    for i, key in enumerate(horizons.keys()):
        vis = [False] * len(horizons) + [True]  # última traza = punto compra
        vis[i] = True
        buttons.append(dict(label=key, method="update", args=[{"visible": vis}]))

    fig.update_layout(
        title=f"Análisis Fibonacci interactivo - {symbol}",
        xaxis_title="Fecha",
        yaxis_title="Precio",
        updatemenus=[{
            "buttons": buttons,
            "direction": "down",
            "showactive": True,
            "x": 0.0,
            "xanchor": "left",
            "y": 1.15,
            "yanchor": "top"
        }],
        height=600
    )

    fig.show()

# %%
def plot_vegas_channel(data, symbol, meta=None):
    """
    Plot the stock's closing prices along with the Vegas Tunnel (144 and 169 EMAs) and shorter-term EMAs.
    """
    # Info about stock
    stock = yf.Ticker(symbol)
    info = stock.info
    try:
        sector = info['sector'] or "Undef"
    except KeyError:
        sector = "ETF"
    
    latest_close = float(data['Close'].iloc[-1])  # <- forzamos tipo escalar
    latest_date = data.index[-1]
    #data['Volume'] = pd.to_numeric(data['Volume'], errors='coerce')

    # Identify support levels
    support_levels = identify_support_levels(data)
    
    # create subplots so I can see volume of stocks
    fig, (ax1, ax2) = plt.subplots(2, figsize=(12,10), sharex=True, gridspec_kw={'height_ratios': [3,1]})
    #plt.figure(figsize=(14, 8))
    
    # Plot the closing prices
    # plt.plot(data['Close'], label='Close Price', color='blue', alpha=0.5)
    ax1.plot(data['Close'], label='Close Price', color='blue', alpha=0.5)
    
    # Plot the Vegas Tunnel (EMA 144 and EMA 169)
    # plt.plot(data['EMA_144'], label='EMA 144', color='green', linestyle='--')
    ax1.plot(data['EMA_144'], label='EMA 144', color='green', linestyle='--')
    # plt.plot(data['EMA_169'], label='EMA 169', color='red', linestyle='--')
    ax1.plot(data['EMA_169'], label='EMA 169', color='red', linestyle='--')
    
    # Plot the shorter-term EMAs (EMA 12 and EMA 24)
    # plt.plot(data['EMA_12'], label='EMA 12', color='purple')
    ax1.plot(data['EMA_12'], label='EMA 12', color='purple')
    # plt.plot(data['EMA_24'], label='EMA 24', color='orange')
    ax1.plot(data['EMA_24'], label='EMA 24', color='orange')
    
    # Hightlight latest close price
    # plt.scatter(latest_date, latest_close, color='black', zorder=5, label=f"Latests Close: {latest_close:.2f}")
    # ax1.scatter(latest_date, latest_close, color='black', zorder=5, label=f"Latests Close: {latest_close:.2f}")
    ax1.scatter(latest_date, latest_close, color='black', zorder=5, label=f"Latest Close: {latest_close:.2f}")
    # plt.axhline(latest_close, color='black', linestyle=':', alpha=0.7)
    # ax1.axhline(latest_close, color='black', linestyle=':', alpha=0.7)
    ax1.axhline(latest_close, color='black', linestyle=':', alpha=0.7)
    
    # Plot support levels
    for level in support_levels:
        ax1.axhline(level, color='purple', linestyle='--', alpha=0.5, label=f'Support Level: {level:.2f}')

    # Customize the plot
    # plt.title(f'Vegas Channel Analysis for {symbol}')
    ax1.set_title(f'{latest_date}-Vegas Channel Analysis for {symbol}-{sector}')
    # plt.xlabel('Date')
    # plt.ylabel('Price')
    ax1.set_ylabel('Price')
    # plt.legend()
    ax1.legend(loc='best')
    # plt.grid(True)
    ax1.grid(True)
    
    # Plot volume on ax2
    #print(data.index[:5])
    #print(type(data.index))
    #print(len(data), len(data['Volume']))
    #ax2.bar(data.index.to_numpy(), data['Volume'].to_numpy(), color='gold', alpha=0.7)
    # Agregar cuadro informativo con info clave de la acción
    if meta:
        text_info = (
            f"Precio actual: {meta.get('Precio actual', 'N/A')}\n"
            f"Rango diario: {meta.get('Rango diario', 'N/A')}\n"
            f"Rango 52 semanas: {meta.get('Rango 52 semanas', 'N/A')}"
        )

        # Mostrar donde no estorbe
        ax1.text(0.5, 0.02, text_info,
                 transform=ax1.transAxes,
                 fontsize=9,
                 verticalalignment='bottom',
                 horizontalalignment='center',
                 bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.5))
    
    #ax2.bar(data.index, data['Volume'], color='gold', alpha=0.7)
    #ax2.set_ylabel('Volume')
    #ax2.set_xlabel('Date')
    #ax2.grid(True)
    #ax2.bar(data.index, data[('Volume', symbol)], color='gold', alpha=0.7)
    ax2.bar(data.index, data['Volume'], color='gold', alpha=0.7)
    ax2.set_ylabel('Volume')
    ax2.set_xlabel('Date')
    ax2.grid(True)
    # Agregar los niveles de Fibonacci:
    add_fibonacci_levels(ax1, data)
    
    # adjust layout
    plt.tight_layout()
    plt.show()

# %%
def plot_candlestick_with_vegas_and_support(data, symbol):
    """
    Plot candlesticks, Vegas channels, support levels, and volume.
    """
    # Prepare figure and subplots
    fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 10), sharex=True, gridspec_kw={'height_ratios': [3, 1]})
    
    # Convert date index to numeric x-coordinates for consistent plotting
    data['Date_num'] = mdates.date2num(data.index)  # Convert datetime index to numeric
    x_coords = data['Date_num']
    # Format date for x-axis
    ax1.xaxis_date()
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    fig.autofmt_xdate()


    # Plot candlesticks
    for i in range(len(data)):
        open_price = data['Open'][i]
        close_price = data['Close'][i]
        high_price = data['High'][i]
        low_price = data['Low'][i]
        
        # Color settings for up (green) and down (red) candles
        color = 'green' if close_price >= open_price else 'red'
        
        # Draw the candle's body
        #ax1.add_patch(plt.Rectangle((i - 0.2, min(open_price, close_price)),
        #                            0.4, abs(close_price - open_price),
        #                            color=color, alpha=0.6))
        ax1.add_patch(plt.Rectangle((x_coords[i] - 0.2, min(open_price, close_price)),0.4, abs(close_price - open_price),color=color, alpha=0.6))
        
        # Draw the candle's wick
        #ax1.plot([i, i], [low_price, high_price], color=color, linewidth=0.8)
        ax1.plot([x_coords[i], x_coords[i]], [low_price, high_price], color=color, linewidth=0.8)

    # Plot the Vegas channels
    ax1.plot(data.index, data['EMA_144'], label='EMA 144', color='green', linestyle='--')
    ax1.plot(data.index, data['EMA_169'], label='EMA 169', color='orange', linestyle='--')
    ax1.plot(data.index, data['EMA_576'], label='EMA 576', color='red', linestyle='--')

    # Highlight latest close price
    latest_close = data['Close'].iloc[-1]
    latest_date = data.index[-1]
    ax1.scatter(latest_date, latest_close, color='black', zorder=5, label=f'Latest Close: {latest_close:.2f}')
    ax1.axhline(latest_close, color='black', linestyle=':', alpha=0.7)

    # Plot support levels
#    support_levels = identify_support_levels(data)
#    for level in support_levels:
#        ax1.axhline(level, color='purple', linestyle='--', alpha=0.5, label=f'Support Level: {level:.2f}')

    # Labels and legend for ax1 (price chart)
    ax1.set_title(f"Candlestick Chart with Vegas Channels and Support Levels for {symbol}")
    ax1.set_ylabel('Price')
    ax1.legend(loc='best')
    ax1.grid(True)

    # Plot volume on ax2
    ax2.bar(data.index, data['Volume'], color='gray', alpha=0.7)
    ax2.set_ylabel('Volume')
    ax2.set_xlabel('Date')
    ax2.grid(True)

    # Adjust layout and show the plot
    plt.tight_layout()
    plt.show()

# %%
def plot_elliott_wave(prices, peaks, troughs, title="Elliott Wave Analysis"):
    """
    Plot the price data with detected Elliott wave points (peaks and troughs).
    
    Parameters:
    - prices (pd.Series): The price data to plot.
    - peaks (list): Indices of local maxima.
    - troughs (list): Indices of local minima.
    - title (str): Title of the chart.
    """
    plt.figure(figsize=(14, 8))
    plt.plot(prices, label='Stock Price', color='blue', alpha=0.7)
    
    # Highlight peaks and troughs
    #plt.scatter(peaks, prices[peaks], color='green', label='Peaks (Wave Highs)', marker='o')
    #plt.scatter(troughs, prices[troughs], color='red', label='Troughs (Wave Lows)', marker='o')
    
    plt.scatter(prices.index[peaks], prices.iloc[peaks], color='green', label='Peaks (Wave Highs)', marker='o')
    plt.scatter(prices.index[troughs], prices.iloc[troughs], color='red', label='Troughs (Wave Lows)', marker='o')
    
    # Connect wave points
    wave_points = sorted(list(peaks) + list(troughs))
    #plt.plot(wave_points, prices[wave_points], color='orange', linestyle='--', label='Elliott Wave')
    plt.plot(prices.index[wave_points], prices.iloc[wave_points], color='orange', linestyle='--', label='Elliott Wave')
    
    plt.title(title)
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Stock symbol and date range
symbol = 'TSLA'  # Apple stock
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

#Fibonaci levels
#plot_fibonacci_horizons(stock_data, symbol, '2024-12-26', 439.59)
plot_fibonacci_interactive(stock_data, 'TSLA', buy_date='2024-12-26', buy_price=439.59)

plt.close()

# %%
# Stock symbol and date range
symbol = 'AAPL'  # Apple stock
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
# Fibonacci levels
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'BTC'  # BitCoin ETF
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'ALFAA.MX'  # Grupo Alfa
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'LLY.MX'  # Elli Lilly and Company
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'PFE.MX'  # Pfizer
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'PDD'  # Pin Duoduo (china)
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'MSTR'  # Microstrategy
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'MCD'  # MacDonalds
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'QQQ'  # Invesco QQQ (AI ETF)
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'BAI'  # iShares AI innovation
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'TSM'  # Taiwan Semi Conductor
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'GENTERA.MX'  # Example: Apple stock
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'BLK'  # Black Rock
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range with Elliot Wave analysis
symbol = 'BLK'  # Black Rock
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 10
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Step 1: Download the stock data
elliot_stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Step 2: Identify peaks and troughs
#elliot_close_prices = elliot_stock_data['Close']
elliot_close_prices = elliot_stock_data[('Close', 'BLK')]
# test
print(type(elliot_stock_data))
print(elliot_stock_data.head())
print(elliot_stock_data.columns)
print(type(elliot_close_prices))
print(elliot_close_prices.head())
print(elliot_close_prices.shape)
print(elliot_close_prices.dtype)

distance = 5
peaks, troughs = identify_peaks_and_troughs(elliot_close_prices, distance=distance)

# Step 3: Plot the Elliott wave analysis
plot_elliott_wave(elliot_close_prices, peaks, troughs, title=f"Elliott Wave Analysis for {symbol}")
plt.close()

# %%
# Stock symbol and date range
symbol = 'NFLX'  # Netflix
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range with Elliot Wave analysis
symbol = 'NFLX'  # Netflix
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 10
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Step 1: Download the stock data
elliot_stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Step 2: Identify peaks and troughs
#elliot_close_prices = elliot_stock_data['Close']
elliot_close_prices = elliot_stock_data[('Close', 'NFLX')]

distance = 5
peaks, troughs = identify_peaks_and_troughs(elliot_close_prices, distance=distance)

# Step 3: Plot the Elliott wave analysis
plot_elliott_wave(elliot_close_prices, peaks, troughs, title=f"Elliott Wave Analysis for {symbol}")
plt.close()

# %%
# Stock symbol and date range
symbol = 'TSLA'  # Tesla
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
plot_vegas_channel(stock_data, symbol, stock_meta)
plt.close()

# %%
# Stock symbol and date range
symbol = 'NVDA'  # NVidia
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
#stock_data = download_stock_data(symbol, start=start_date, end=end_date)
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

# Plot the result
#plot_vegas_channel(stock_data, symbol)
plot_vegas_channel(stock_data, symbol, meta=stock_meta)
plt.close()

# %%
def get_stock_info(symbol):
    stock = yf.Ticker(symbol)
    info = stock.info

    try:
        current_price = info.get("currentPrice")
        day_low = info.get("dayLow")
        day_high = info.get("dayHigh")
        week_52_low = info.get("fiftyTwoWeekLow")
        week_52_high = info.get("fiftyTwoWeekHigh")

        return {
            "Símbolo": symbol,
            "Precio actual": current_price,
            "Rango diario": f"{day_low} - {day_high}",
            "Rango 52 semanas": f"{week_52_low} - {week_52_high}"
        }
    except Exception as e:
        return {"Error": str(e)}

# Ejemplo
get_stock_info("NVDA")

# %%
# Stock symbol and date range
symbol = 'NVDA'  # NVidia
today = datetime.date.today()
# choose days = week_days * number_weeks ago
w_days = 7
n_weeks = 51
# some weeks from now
ago_weeks = datetime.timedelta(days=w_days * n_weeks)
last_weeks = today - ago_weeks
#start_date = '2023-01-01'
start_date = last_weeks
#end_date = '2023-10-10'
end_date = today

# Download stock data
#stock_data = download_stock_data(symbol, start=start_date, end=end_date)
stock_data, stock_meta = download_stock_data(symbol, start=start_date, end=end_date)

# Perform Vegas Channel Analysis (calculate EMAs)
stock_data = vegas_channel_analysis(stock_data)

print(stock_data)
