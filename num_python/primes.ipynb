# %%
# https://stackoverflow.com/questions/3277503/how-to-read-a-file-line-by-line-into-a-list
filename = "../../JS/nodeJS/Eulers/utils/primes1.txt"
with open(filename) as file:
    lines = [int(line.rstrip()) for line in file]

# %%
len(lines)
# Out:
# 470385

# %%
# https://stackoverflow.com/questions/8409095/set-markers-for-individual-points-on-a-line
import numpy as np
import matplotlib.pyplot as plt

x = lines
y = np.zeros(len(lines), dtype=int)

plt.plot(x, y, linestyle='-', marker='o', color='b')

# %%
# seems a continuos, see by fractions
